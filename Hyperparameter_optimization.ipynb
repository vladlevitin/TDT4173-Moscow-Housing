# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_log_error
import re
from haversine import haversine, Unit
import lightgbm as lgb
from sklearn import preprocessing
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
from sklearn.linear_model import LinearRegression
import xgboost
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import BayesianRidge
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
import optuna

# %%
dfTrain = pd.read_csv("prepared_data/apartments_and_building_train.csv")
dfTest = pd.read_csv("prepared_data/apartments_and_building_test.csv")

# %%
def get_distance_center(lat1, lon1):
    dist = haversine((lat1, lon1), (55.751244, 37.618423), unit=Unit.METERS)
    return round(dist/1000, 3)

def get_shortest_distance(lat, lon, coordinates):
    shortest = np.inf
    for coord in coordinates:
        dist = haversine(coord, (lat, lon), unit=Unit.METERS)
        if dist < shortest:
            shortest = dist
    if shortest == np.inf:
        return 100
    return round(shortest/1000, 3)

# %%
dfTrain["distance_center"] = dfTrain.loc[:, "latitude":"longitude"].apply(lambda x: get_distance_center(x.latitude, x.longitude), axis=1)
dfTest["distance_center"] = dfTest.loc[:, "latitude":"longitude"].apply(lambda x: get_distance_center(x.latitude, x.longitude), axis=1)

# %%
def add_distance_to(target, df_train, df_test):
    targets = pd.read_csv(f"prepared_data/extra_features/{target}.csv")
    coordinates = targets.values.tolist()

    df_train[f"distance_{target}"] = df_train.loc[:, "latitude":"longitude"].apply(lambda x: get_shortest_distance(x.latitude, x.longitude, coordinates), axis=1)
    df_test[f"distance_{target}"] = df_test.loc[:, "latitude":"longitude"].apply(lambda x: get_shortest_distance(x.latitude, x.longitude, coordinates), axis=1)

""" positive """
add_distance_to("metro", dfTrain, dfTest)
add_distance_to("university", dfTrain, dfTest)
add_distance_to("shopping_center", dfTrain, dfTest)
add_distance_to("park", dfTrain, dfTest)
add_distance_to("golf_course", dfTrain, dfTest)
""" negative """
add_distance_to("airport", dfTrain, dfTest)
add_distance_to("prison", dfTrain, dfTest)

# %%
def process_data(dataframe, keep_col):
    remove_columns = ['street', 'address', 'building_id', 'id_y', 'id_x', 'price']
    
    for col in keep_col:
        remove_columns.remove(col)

    dataframe = dataframe.drop(remove_columns, axis=1)

    return dataframe

# %% [markdown]
# # Optimize parameters

# %% [markdown]
# ## LGBMRegression

# %%
# normalize training data
train_data = dfTrain.copy()
train_data = process_data(train_data, keep_col=['price'])

# split training data into test and training split
X_train, X_test = train_test_split(train_data, test_size=0.10, random_state=42)

# remove apartments with very high price from training data
qhigh = X_train["price"].quantile(0.999)
X_train = X_train[(train_data["price"] < qhigh)]

# get price columns 
y_train = X_train.pop("price")
y_test = X_test.pop("price")

cols = X_train.columns

# log prices
y_train = np.log(y_train)

scaler = preprocessing.StandardScaler().fit(X_train)
imputor=IterativeImputer(
    estimator=BayesianRidge(),
    imputation_order='ascending', 
    max_iter=100,
    tol=1e-5)

X_train = imputor.fit_transform(X_train)
X_train = scaler.transform(X_train)

X_test = imputor.fit_transform(X_test)
X_test = scaler.transform(X_test)


"""
lgbm_regressor = lgb.LGBMRegressor(
    num_leaves=62,
    max_depth=80, 
    random_state=42,
    metric='rmse',
    n_jobs=5, 
    n_estimators=3821,
    colsample_bytree=0.5466374179397641,
    subsample=0.9925544863710687,
    learning_rate=0.041096962826700785
)
"""

def objective(trial):
    num_leaves = trial.suggest_int('num_leaves', 50, 74)
    max_depth = trial.suggest_int('max_depth', 60, 100)
    n_jobs = trial.suggest_int('n_jobs', 3, 7)
    n_estimators = trial.suggest_int('n_estimators', 3500, 4120)
    colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.44, 0.64)
    subsample = trial.suggest_uniform('subsample', 0.9, 1)
    learning_rate = trial.suggest_uniform('learning_rate', 0.02, 0.06)

    clf = lgb.LGBMRegressor(
        num_leaves=num_leaves,
        max_depth=max_depth, 
        random_state=42,
        metric='rmse',
        n_jobs=n_jobs, 
        n_estimators=n_estimators,
        colsample_bytree=colsample_bytree,
        subsample=subsample,
        learning_rate=learning_rate
    )

    clf.fit(X_train, y_train)
    lgbm_prediction = clf.predict(X_test, num_iteration=clf.best_iteration_)
    lgbm_prediction = np.exp(lgbm_prediction)

    return np.sqrt(mean_squared_log_error(lgbm_prediction, y_test))

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=100)
print(study.best_trial)

# 'num_leaves': 57, 'max_depth': 86, 'n_jobs': 5, 'n_estimators': 3708, 'colsample_bytree': 0.4811674364805376, 'subsample': 0.9293927819656886, 'learning_rate': 0.05183967241031373
# 'num_leaves': 52, 'max_depth': 75, 'n_jobs': 4, 'n_estimators': 3640, 'colsample_bytree': 0.48432530282059805, 'subsample': 0.9272124012179532, 'learning_rate': 0.05084923664278231

# %% [markdown]
# ## XGBoost

# %%
# normalize training data
train_data = dfTrain.copy()
train_data = process_data(train_data, keep_col=['price'])

# split training data into test and training split
X_train, X_test = train_test_split(train_data, test_size=0.10, random_state=42)

# remove apartments with very high price from training data
qhigh = X_train["price"].quantile(0.999)
X_train = X_train[(train_data["price"] < qhigh)]

# get price columns 
y_train = X_train.pop("price")
y_test = X_test.pop("price")

cols = X_train.columns

# log prices
y_train = np.log(y_train)

scaler = preprocessing.StandardScaler().fit(X_train)
imputor=IterativeImputer(
    estimator=BayesianRidge(),
    imputation_order='ascending', 
    max_iter=100,
    tol=1e-5)

X_train = imputor.fit_transform(X_train)
X_train = scaler.transform(X_train)

X_test = imputor.fit_transform(X_test)
X_test = scaler.transform(X_test)


"""
xgboost_regressor=xgboost.XGBRegressor(
    base_score=0.6809801659452004, booster='gbtree', colsample_bylevel=1,
    colsample_bynode=1, colsample_bytree=0.7880864100886343, enable_categorical=False,
    gamma=0, gpu_id=-1, importance_type=None,
    interaction_constraints='', learning_rate=0.04158422646007316, max_delta_step=0,
    max_depth=12, min_child_weight=7,
    monotone_constraints='()', n_estimators=1894, n_jobs=16,
    num_parallel_tree=1, predictor='auto', random_state=42, reg_alpha=0,
    reg_lambda=1, scale_pos_weight=1, subsample=0.8295598441506259, tree_method='exact',
    validate_parameters=1, verbosity=None, objective='reg:squarederror'
)
"""

def objective(trial):
    base_score = trial.suggest_uniform('base_score', 0.6, 0.76)
    max_depth = trial.suggest_int('max_depth', 10, 14)
    n_jobs = trial.suggest_int('n_jobs', 14, 18)
    min_child_weight = trial.suggest_int('min_child_weight', 6, 10)
    n_estimators = trial.suggest_int('n_estimators', 1594, 2194)
    colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.7, 0.86)
    subsample = trial.suggest_uniform('subsample', 0.73, 0.9)
    learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.06)

    clf=xgboost.XGBRegressor(base_score=base_score, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=colsample_bytree,
             gamma=0, gpu_id=-1, importance_type=None,
             interaction_constraints='', learning_rate=learning_rate, max_delta_step=0,
             max_depth=max_depth, min_child_weight=min_child_weight,
             monotone_constraints='()', n_estimators=n_estimators, n_jobs=n_jobs,
             num_parallel_tree=1, predictor='auto', random_state=42, reg_alpha=0,
             reg_lambda=1, scale_pos_weight=1, subsample=subsample, tree_method='exact',
             validate_parameters=1, verbosity=None, objective='reg:squarederror',
             enable_categorical=False)

    clf.fit(X_train, y_train, early_stopping_rounds=10, eval_set=[(X_train, y_train), (X_test, np.log(y_test))])
    xgboost_prediction = clf.predict(X_test)
    xgboost_prediction = np.exp(xgboost_prediction)

    return np.sqrt(mean_squared_log_error(xgboost_prediction, y_test))

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=10)
print(study.best_trial)
# Out:
# C:\Users\erikm\AppData\Local\Temp/ipykernel_6748/2994307437.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   X_train = X_train[(train_data["price"] < qhigh)]
# C:\Users\erikm\miniconda3\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# C:\Users\erikm\miniconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\erikm\miniconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2021-11-16 20:28:07,527] A new study created in memory with name: no-name-7d44a243-1a1b-46e7-a7f2-2396a452d068
# [20:28:07] WARNING: ..\src\learner.cc:541:
# Parameters: { enable_categorical } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-rmse:14.93111	validation_1-rmse:14.93187
# [1]	validation_0-rmse:14.19897	validation_1-rmse:14.20022
# [2]	validation_0-rmse:13.50282	validation_1-rmse:13.50436
# [3]	validation_0-rmse:12.84087	validation_1-rmse:12.84309
# [4]	validation_0-rmse:12.21158	validation_1-rmse:12.21448
# [5]	validation_0-rmse:11.61303	validation_1-rmse:11.61655
# [6]	validation_0-rmse:11.04392	validation_1-rmse:11.04781
# [7]	validation_0-rmse:10.50268	validation_1-rmse:10.50703
# [8]	validation_0-rmse:9.98807	validation_1-rmse:9.99289
# [9]	validation_0-rmse:9.49854	validation_1-rmse:9.50393
# [10]	validation_0-rmse:9.03317	validation_1-rmse:9.03886
# [11]	validation_0-rmse:8.59063	validation_1-rmse:8.59697
# [12]	validation_0-rmse:8.16984	validation_1-rmse:8.17635
# [13]	validation_0-rmse:7.76974	validation_1-rmse:7.77632
# [14]	validation_0-rmse:7.38930	validation_1-rmse:7.39620
# [15]	validation_0-rmse:7.02751	validation_1-rmse:7.03471
# [16]	validation_0-rmse:6.68352	validation_1-rmse:6.69105
# [17]	validation_0-rmse:6.35647	validation_1-rmse:6.36433
# [18]	validation_0-rmse:6.04531	validation_1-rmse:6.05323
# [19]	validation_0-rmse:5.74950	validation_1-rmse:5.75749
# [20]	validation_0-rmse:5.46828	validation_1-rmse:5.47627
# [21]	validation_0-rmse:5.20091	validation_1-rmse:5.20925
# [22]	validation_0-rmse:4.94659	validation_1-rmse:4.95494
# [23]	validation_0-rmse:4.70474	validation_1-rmse:4.71315
# [24]	validation_0-rmse:4.47471	validation_1-rmse:4.48301
# [25]	validation_0-rmse:4.25600	validation_1-rmse:4.26446
# [26]	validation_0-rmse:4.04808	validation_1-rmse:4.05660
# [27]	validation_0-rmse:3.85042	validation_1-rmse:3.85919
# [28]	validation_0-rmse:3.66247	validation_1-rmse:3.67107
# [29]	validation_0-rmse:3.48377	validation_1-rmse:3.49259
# [30]	validation_0-rmse:3.31385	validation_1-rmse:3.32295
# [31]	validation_0-rmse:3.15234	validation_1-rmse:3.16159
# [32]	validation_0-rmse:2.99880	validation_1-rmse:3.00810
# [33]	validation_0-rmse:2.85274	validation_1-rmse:2.86203
# [34]	validation_0-rmse:2.71380	validation_1-rmse:2.72295
# [35]	validation_0-rmse:2.58177	validation_1-rmse:2.59080
# [36]	validation_0-rmse:2.45624	validation_1-rmse:2.46523
# [37]	validation_0-rmse:2.33690	validation_1-rmse:2.34598
# [38]	validation_0-rmse:2.22340	validation_1-rmse:2.23238
# [39]	validation_0-rmse:2.11554	validation_1-rmse:2.12475
# [40]	validation_0-rmse:2.01309	validation_1-rmse:2.02240
# [41]	validation_0-rmse:1.91555	validation_1-rmse:1.92499
# [42]	validation_0-rmse:1.82290	validation_1-rmse:1.83248
# [43]	validation_0-rmse:1.73478	validation_1-rmse:1.74432
# [44]	validation_0-rmse:1.65097	validation_1-rmse:1.66084
# [45]	validation_0-rmse:1.57140	validation_1-rmse:1.58119
# [46]	validation_0-rmse:1.49577	validation_1-rmse:1.50549
# [47]	validation_0-rmse:1.42388	validation_1-rmse:1.43350
# [48]	validation_0-rmse:1.35551	validation_1-rmse:1.36517
# [49]	validation_0-rmse:1.29055	validation_1-rmse:1.30030
# [50]	validation_0-rmse:1.22880	validation_1-rmse:1.23852
# [51]	validation_0-rmse:1.17010	validation_1-rmse:1.17996
# [52]	validation_0-rmse:1.11429	validation_1-rmse:1.12453
# [53]	validation_0-rmse:1.06133	validation_1-rmse:1.07159
# [54]	validation_0-rmse:1.01089	validation_1-rmse:1.02120
# [55]	validation_0-rmse:0.96301	validation_1-rmse:0.97361
# [56]	validation_0-rmse:0.91743	validation_1-rmse:0.92813
# [57]	validation_0-rmse:0.87421	validation_1-rmse:0.88501
# [58]	validation_0-rmse:0.83318	validation_1-rmse:0.84396
# [59]	validation_0-rmse:0.79414	validation_1-rmse:0.80490
# [60]	validation_0-rmse:0.75699	validation_1-rmse:0.76769
# [61]	validation_0-rmse:0.72182	validation_1-rmse:0.73275
# [62]	validation_0-rmse:0.68834	validation_1-rmse:0.69964
# [63]	validation_0-rmse:0.65658	validation_1-rmse:0.66812
# [64]	validation_0-rmse:0.62644	validation_1-rmse:0.63832
# [65]	validation_0-rmse:0.59779	validation_1-rmse:0.60970
# [66]	validation_0-rmse:0.57064	validation_1-rmse:0.58284
# [67]	validation_0-rmse:0.54479	validation_1-rmse:0.55725
# [68]	validation_0-rmse:0.52016	validation_1-rmse:0.53302
# [69]	validation_0-rmse:0.49683	validation_1-rmse:0.51003
# [70]	validation_0-rmse:0.47467	validation_1-rmse:0.48819
# [71]	validation_0-rmse:0.45361	validation_1-rmse:0.46753
# [72]	validation_0-rmse:0.43369	validation_1-rmse:0.44801
# [73]	validation_0-rmse:0.41465	validation_1-rmse:0.42931
# [74]	validation_0-rmse:0.39665	validation_1-rmse:0.41159
# [75]	validation_0-rmse:0.37960	validation_1-rmse:0.39489
# [76]	validation_0-rmse:0.36337	validation_1-rmse:0.37917
# [77]	validation_0-rmse:0.34803	validation_1-rmse:0.36441
# [78]	validation_0-rmse:0.33343	validation_1-rmse:0.35031
# [79]	validation_0-rmse:0.31960	validation_1-rmse:0.33719
# [80]	validation_0-rmse:0.30656	validation_1-rmse:0.32480
# [81]	validation_0-rmse:0.29430	validation_1-rmse:0.31329
# [82]	validation_0-rmse:0.28257	validation_1-rmse:0.30220
# [83]	validation_0-rmse:0.27135	validation_1-rmse:0.29143
# [84]	validation_0-rmse:0.26084	validation_1-rmse:0.28173
# [85]	validation_0-rmse:0.25080	validation_1-rmse:0.27230
# [86]	validation_0-rmse:0.24142	validation_1-rmse:0.26366
# [87]	validation_0-rmse:0.23255	validation_1-rmse:0.25551
# [88]	validation_0-rmse:0.22416	validation_1-rmse:0.24807
# [89]	validation_0-rmse:0.21627	validation_1-rmse:0.24099
# [90]	validation_0-rmse:0.20859	validation_1-rmse:0.23402
# [91]	validation_0-rmse:0.20142	validation_1-rmse:0.22769
# [92]	validation_0-rmse:0.19478	validation_1-rmse:0.22169
# [93]	validation_0-rmse:0.18841	validation_1-rmse:0.21605
# [94]	validation_0-rmse:0.18242	validation_1-rmse:0.21085
# [95]	validation_0-rmse:0.17674	validation_1-rmse:0.20593
# [96]	validation_0-rmse:0.17148	validation_1-rmse:0.20148
# [97]	validation_0-rmse:0.16656	validation_1-rmse:0.19728
# [98]	validation_0-rmse:0.16181	validation_1-rmse:0.19336
# [99]	validation_0-rmse:0.15739	validation_1-rmse:0.18968
# [100]	validation_0-rmse:0.15324	validation_1-rmse:0.18634
# [101]	validation_0-rmse:0.14918	validation_1-rmse:0.18305
# [102]	validation_0-rmse:0.14530	validation_1-rmse:0.17989
# [103]	validation_0-rmse:0.14177	validation_1-rmse:0.17728
# [104]	validation_0-rmse:0.13843	validation_1-rmse:0.17474
# [105]	validation_0-rmse:0.13523	validation_1-rmse:0.17228
# [106]	validation_0-rmse:0.13236	validation_1-rmse:0.17008
# [107]	validation_0-rmse:0.12961	validation_1-rmse:0.16788
# [108]	validation_0-rmse:0.12715	validation_1-rmse:0.16594
# [109]	validation_0-rmse:0.12472	validation_1-rmse:0.16406
# [110]	validation_0-rmse:0.12244	validation_1-rmse:0.16226
# [111]	validation_0-rmse:0.12015	validation_1-rmse:0.16083
# [112]	validation_0-rmse:0.11811	validation_1-rmse:0.15933
# [113]	validation_0-rmse:0.11620	validation_1-rmse:0.15799
# [114]	validation_0-rmse:0.11432	validation_1-rmse:0.15655
# [115]	validation_0-rmse:0.11239	validation_1-rmse:0.15526
# [116]	validation_0-rmse:0.11075	validation_1-rmse:0.15421
# [117]	validation_0-rmse:0.10918	validation_1-rmse:0.15321
# [118]	validation_0-rmse:0.10770	validation_1-rmse:0.15239
# [119]	validation_0-rmse:0.10637	validation_1-rmse:0.15136
# [120]	validation_0-rmse:0.10516	validation_1-rmse:0.15053
# [121]	validation_0-rmse:0.10394	validation_1-rmse:0.14984
# [122]	validation_0-rmse:0.10289	validation_1-rmse:0.14921
# [123]	validation_0-rmse:0.10165	validation_1-rmse:0.14851
# [124]	validation_0-rmse:0.10057	validation_1-rmse:0.14796
# [125]	validation_0-rmse:0.09958	validation_1-rmse:0.14740
# [126]	validation_0-rmse:0.09862	validation_1-rmse:0.14688
# [127]	validation_0-rmse:0.09768	validation_1-rmse:0.14631
# [128]	validation_0-rmse:0.09684	validation_1-rmse:0.14566
# [129]	validation_0-rmse:0.09607	validation_1-rmse:0.14520
# [130]	validation_0-rmse:0.09532	validation_1-rmse:0.14466
# [131]	validation_0-rmse:0.09460	validation_1-rmse:0.14428
# [132]	validation_0-rmse:0.09372	validation_1-rmse:0.14371
# [133]	validation_0-rmse:0.09304	validation_1-rmse:0.14345
# [134]	validation_0-rmse:0.09233	validation_1-rmse:0.14317
# [135]	validation_0-rmse:0.09145	validation_1-rmse:0.14268
# [136]	validation_0-rmse:0.09093	validation_1-rmse:0.14229
# [137]	validation_0-rmse:0.09035	validation_1-rmse:0.14196
# [138]	validation_0-rmse:0.08974	validation_1-rmse:0.14161
# [139]	validation_0-rmse:0.08912	validation_1-rmse:0.14137
# [140]	validation_0-rmse:0.08866	validation_1-rmse:0.14110
# [141]	validation_0-rmse:0.08800	validation_1-rmse:0.14076
# [142]	validation_0-rmse:0.08746	validation_1-rmse:0.14056
# [143]	validation_0-rmse:0.08716	validation_1-rmse:0.14037
# [144]	validation_0-rmse:0.08674	validation_1-rmse:0.14013
# [145]	validation_0-rmse:0.08634	validation_1-rmse:0.13986
# [146]	validation_0-rmse:0.08593	validation_1-rmse:0.13969
# [147]	validation_0-rmse:0.08548	validation_1-rmse:0.13939
# [148]	validation_0-rmse:0.08514	validation_1-rmse:0.13921
# [149]	validation_0-rmse:0.08469	validation_1-rmse:0.13895
# [150]	validation_0-rmse:0.08429	validation_1-rmse:0.13877
# [151]	validation_0-rmse:0.08405	validation_1-rmse:0.13864
# [152]	validation_0-rmse:0.08378	validation_1-rmse:0.13841
# [153]	validation_0-rmse:0.08347	validation_1-rmse:0.13830
# [154]	validation_0-rmse:0.08315	validation_1-rmse:0.13813
# [155]	validation_0-rmse:0.08266	validation_1-rmse:0.13788
# [156]	validation_0-rmse:0.08216	validation_1-rmse:0.13769
# [157]	validation_0-rmse:0.08183	validation_1-rmse:0.13758
# [158]	validation_0-rmse:0.08157	validation_1-rmse:0.13749
# [159]	validation_0-rmse:0.08136	validation_1-rmse:0.13733
# [160]	validation_0-rmse:0.08094	validation_1-rmse:0.13717
# [161]	validation_0-rmse:0.08072	validation_1-rmse:0.13705
# [162]	validation_0-rmse:0.08029	validation_1-rmse:0.13697
# [163]	validation_0-rmse:0.07988	validation_1-rmse:0.13685
# [164]	validation_0-rmse:0.07962	validation_1-rmse:0.13673
# [165]	validation_0-rmse:0.07932	validation_1-rmse:0.13667
# [166]	validation_0-rmse:0.07875	validation_1-rmse:0.13650
# [167]	validation_0-rmse:0.07858	validation_1-rmse:0.13640
# [168]	validation_0-rmse:0.07835	validation_1-rmse:0.13630
# [169]	validation_0-rmse:0.07814	validation_1-rmse:0.13616
# [170]	validation_0-rmse:0.07783	validation_1-rmse:0.13602
# [171]	validation_0-rmse:0.07761	validation_1-rmse:0.13595
# [172]	validation_0-rmse:0.07751	validation_1-rmse:0.13590
# [173]	validation_0-rmse:0.07717	validation_1-rmse:0.13586
# [174]	validation_0-rmse:0.07673	validation_1-rmse:0.13580
# [175]	validation_0-rmse:0.07646	validation_1-rmse:0.13567
# [176]	validation_0-rmse:0.07612	validation_1-rmse:0.13556
# [177]	validation_0-rmse:0.07568	validation_1-rmse:0.13547
# [178]	validation_0-rmse:0.07560	validation_1-rmse:0.13542
# [179]	validation_0-rmse:0.07527	validation_1-rmse:0.13536
# [180]	validation_0-rmse:0.07498	validation_1-rmse:0.13531
# [181]	validation_0-rmse:0.07493	validation_1-rmse:0.13526
# [182]	validation_0-rmse:0.07455	validation_1-rmse:0.13527
# [183]	validation_0-rmse:0.07425	validation_1-rmse:0.13517
# [184]	validation_0-rmse:0.07405	validation_1-rmse:0.13512
# [185]	validation_0-rmse:0.07382	validation_1-rmse:0.13500
# [186]	validation_0-rmse:0.07377	validation_1-rmse:0.13498
# [187]	validation_0-rmse:0.07361	validation_1-rmse:0.13491
# [188]	validation_0-rmse:0.07334	validation_1-rmse:0.13494
# [189]	validation_0-rmse:0.07299	validation_1-rmse:0.13489
# [190]	validation_0-rmse:0.07252	validation_1-rmse:0.13473
# [191]	validation_0-rmse:0.07242	validation_1-rmse:0.13473
# [192]	validation_0-rmse:0.07216	validation_1-rmse:0.13473
# [193]	validation_0-rmse:0.07194	validation_1-rmse:0.13463
# [194]	validation_0-rmse:0.07153	validation_1-rmse:0.13447
# [195]	validation_0-rmse:0.07125	validation_1-rmse:0.13448
# [196]	validation_0-rmse:0.07103	validation_1-rmse:0.13443
# [197]	validation_0-rmse:0.07065	validation_1-rmse:0.13438
# [198]	validation_0-rmse:0.07040	validation_1-rmse:0.13431
# [199]	validation_0-rmse:0.07006	validation_1-rmse:0.13421
# [200]	validation_0-rmse:0.06990	validation_1-rmse:0.13417
# [201]	validation_0-rmse:0.06968	validation_1-rmse:0.13415
# [202]	validation_0-rmse:0.06962	validation_1-rmse:0.13413
# [203]	validation_0-rmse:0.06932	validation_1-rmse:0.13406
# [204]	validation_0-rmse:0.06921	validation_1-rmse:0.13402
# [205]	validation_0-rmse:0.06904	validation_1-rmse:0.13400
# [206]	validation_0-rmse:0.06878	validation_1-rmse:0.13397
# [207]	validation_0-rmse:0.06858	validation_1-rmse:0.13395
# [208]	validation_0-rmse:0.06851	validation_1-rmse:0.13391
# [209]	validation_0-rmse:0.06820	validation_1-rmse:0.13383
# [210]	validation_0-rmse:0.06815	validation_1-rmse:0.13379
# [211]	validation_0-rmse:0.06793	validation_1-rmse:0.13379
# [212]	validation_0-rmse:0.06782	validation_1-rmse:0.13372
# [213]	validation_0-rmse:0.06765	validation_1-rmse:0.13367
# [214]	validation_0-rmse:0.06732	validation_1-rmse:0.13357
# [215]	validation_0-rmse:0.06708	validation_1-rmse:0.13349
# [216]	validation_0-rmse:0.06698	validation_1-rmse:0.13344
# [217]	validation_0-rmse:0.06690	validation_1-rmse:0.13342
# [218]	validation_0-rmse:0.06667	validation_1-rmse:0.13340
# [219]	validation_0-rmse:0.06652	validation_1-rmse:0.13333
# [220]	validation_0-rmse:0.06624	validation_1-rmse:0.13326
# [221]	validation_0-rmse:0.06601	validation_1-rmse:0.13322
# [222]	validation_0-rmse:0.06598	validation_1-rmse:0.13322
# [223]	validation_0-rmse:0.06571	validation_1-rmse:0.13315
# [224]	validation_0-rmse:0.06548	validation_1-rmse:0.13312
# [225]	validation_0-rmse:0.06526	validation_1-rmse:0.13307
# [226]	validation_0-rmse:0.06505	validation_1-rmse:0.13299
# [227]	validation_0-rmse:0.06462	validation_1-rmse:0.13289
# [228]	validation_0-rmse:0.06449	validation_1-rmse:0.13287
# [229]	validation_0-rmse:0.06437	validation_1-rmse:0.13282
# [230]	validation_0-rmse:0.06406	validation_1-rmse:0.13282
# [231]	validation_0-rmse:0.06397	validation_1-rmse:0.13276
# [232]	validation_0-rmse:0.06388	validation_1-rmse:0.13273
# [233]	validation_0-rmse:0.06373	validation_1-rmse:0.13269
# [234]	validation_0-rmse:0.06364	validation_1-rmse:0.13269
# [235]	validation_0-rmse:0.06358	validation_1-rmse:0.13264
# [236]	validation_0-rmse:0.06337	validation_1-rmse:0.13264
# [237]	validation_0-rmse:0.06322	validation_1-rmse:0.13265
# [238]	validation_0-rmse:0.06294	validation_1-rmse:0.13262
# [239]	validation_0-rmse:0.06286	validation_1-rmse:0.13263
# [240]	validation_0-rmse:0.06283	validation_1-rmse:0.13260
# [241]	validation_0-rmse:0.06257	validation_1-rmse:0.13251
# [242]	validation_0-rmse:0.06245	validation_1-rmse:0.13246
# [243]	validation_0-rmse:0.06223	validation_1-rmse:0.13243
# [244]	validation_0-rmse:0.06202	validation_1-rmse:0.13239
# [245]	validation_0-rmse:0.06187	validation_1-rmse:0.13234
# [246]	validation_0-rmse:0.06165	validation_1-rmse:0.13229
# [247]	validation_0-rmse:0.06157	validation_1-rmse:0.13225
# [248]	validation_0-rmse:0.06153	validation_1-rmse:0.13222
# [249]	validation_0-rmse:0.06129	validation_1-rmse:0.13222
# [250]	validation_0-rmse:0.06109	validation_1-rmse:0.13217
# [251]	validation_0-rmse:0.06092	validation_1-rmse:0.13216
# [252]	validation_0-rmse:0.06087	validation_1-rmse:0.13216
# [253]	validation_0-rmse:0.06068	validation_1-rmse:0.13214
# [254]	validation_0-rmse:0.06043	validation_1-rmse:0.13211
# [255]	validation_0-rmse:0.06016	validation_1-rmse:0.13206
# [256]	validation_0-rmse:0.05996	validation_1-rmse:0.13202
# [257]	validation_0-rmse:0.05984	validation_1-rmse:0.13199
# [258]	validation_0-rmse:0.05974	validation_1-rmse:0.13197
# [259]	validation_0-rmse:0.05952	validation_1-rmse:0.13192
# [260]	validation_0-rmse:0.05936	validation_1-rmse:0.13187
# [261]	validation_0-rmse:0.05920	validation_1-rmse:0.13182
# [262]	validation_0-rmse:0.05905	validation_1-rmse:0.13176
# [263]	validation_0-rmse:0.05884	validation_1-rmse:0.13174
# [264]	validation_0-rmse:0.05864	validation_1-rmse:0.13168
# [265]	validation_0-rmse:0.05858	validation_1-rmse:0.13165
# [266]	validation_0-rmse:0.05835	validation_1-rmse:0.13164
# [267]	validation_0-rmse:0.05820	validation_1-rmse:0.13159
# [268]	validation_0-rmse:0.05815	validation_1-rmse:0.13157
# [269]	validation_0-rmse:0.05802	validation_1-rmse:0.13154
# [270]	validation_0-rmse:0.05782	validation_1-rmse:0.13150
# [271]	validation_0-rmse:0.05762	validation_1-rmse:0.13146
# [272]	validation_0-rmse:0.05751	validation_1-rmse:0.13144
# [273]	validation_0-rmse:0.05732	validation_1-rmse:0.13139
# [274]	validation_0-rmse:0.05714	validation_1-rmse:0.13133
# [275]	validation_0-rmse:0.05701	validation_1-rmse:0.13127
# [276]	validation_0-rmse:0.05679	validation_1-rmse:0.13123
# [277]	validation_0-rmse:0.05671	validation_1-rmse:0.13121
# [278]	validation_0-rmse:0.05642	validation_1-rmse:0.13118
# [279]	validation_0-rmse:0.05627	validation_1-rmse:0.13113
# [280]	validation_0-rmse:0.05607	validation_1-rmse:0.13114
# [281]	validation_0-rmse:0.05596	validation_1-rmse:0.13107
# [282]	validation_0-rmse:0.05585	validation_1-rmse:0.13103
# [283]	validation_0-rmse:0.05582	validation_1-rmse:0.13101
# [284]	validation_0-rmse:0.05569	validation_1-rmse:0.13098
# [285]	validation_0-rmse:0.05552	validation_1-rmse:0.13093
# [286]	validation_0-rmse:0.05528	validation_1-rmse:0.13090
# [287]	validation_0-rmse:0.05522	validation_1-rmse:0.13089
# [288]	validation_0-rmse:0.05514	validation_1-rmse:0.13088
# [289]	validation_0-rmse:0.05498	validation_1-rmse:0.13085
# [290]	validation_0-rmse:0.05475	validation_1-rmse:0.13082
# [291]	validation_0-rmse:0.05457	validation_1-rmse:0.13081
# [292]	validation_0-rmse:0.05442	validation_1-rmse:0.13078
# [293]	validation_0-rmse:0.05431	validation_1-rmse:0.13078
# [294]	validation_0-rmse:0.05423	validation_1-rmse:0.13079
# [295]	validation_0-rmse:0.05407	validation_1-rmse:0.13076
# [296]	validation_0-rmse:0.05394	validation_1-rmse:0.13074
# [297]	validation_0-rmse:0.05381	validation_1-rmse:0.13070
# [298]	validation_0-rmse:0.05355	validation_1-rmse:0.13065
# [299]	validation_0-rmse:0.05339	validation_1-rmse:0.13061
# [300]	validation_0-rmse:0.05318	validation_1-rmse:0.13059
# [301]	validation_0-rmse:0.05302	validation_1-rmse:0.13050
# [302]	validation_0-rmse:0.05291	validation_1-rmse:0.13047
# [303]	validation_0-rmse:0.05268	validation_1-rmse:0.13050
# [304]	validation_0-rmse:0.05255	validation_1-rmse:0.13047
# [305]	validation_0-rmse:0.05233	validation_1-rmse:0.13038
# [306]	validation_0-rmse:0.05217	validation_1-rmse:0.13036
# [307]	validation_0-rmse:0.05204	validation_1-rmse:0.13029
# [308]	validation_0-rmse:0.05195	validation_1-rmse:0.13026
# [309]	validation_0-rmse:0.05175	validation_1-rmse:0.13019
# [310]	validation_0-rmse:0.05163	validation_1-rmse:0.13020
# [311]	validation_0-rmse:0.05148	validation_1-rmse:0.13018
# [312]	validation_0-rmse:0.05135	validation_1-rmse:0.13016
# [313]	validation_0-rmse:0.05131	validation_1-rmse:0.13015
# [314]	validation_0-rmse:0.05118	validation_1-rmse:0.13010
# [315]	validation_0-rmse:0.05114	validation_1-rmse:0.13009
# [316]	validation_0-rmse:0.05100	validation_1-rmse:0.13006
# [317]	validation_0-rmse:0.05096	validation_1-rmse:0.13004
# [318]	validation_0-rmse:0.05082	validation_1-rmse:0.13004
# [319]	validation_0-rmse:0.05073	validation_1-rmse:0.13002
# [320]	validation_0-rmse:0.05046	validation_1-rmse:0.12995
# [321]	validation_0-rmse:0.05023	validation_1-rmse:0.12992
# [322]	validation_0-rmse:0.05015	validation_1-rmse:0.12992
# [323]	validation_0-rmse:0.05006	validation_1-rmse:0.12993
# [324]	validation_0-rmse:0.04991	validation_1-rmse:0.12994
# [325]	validation_0-rmse:0.04977	validation_1-rmse:0.12991
# [326]	validation_0-rmse:0.04968	validation_1-rmse:0.12986
# [327]	validation_0-rmse:0.04960	validation_1-rmse:0.12984
# [328]	validation_0-rmse:0.04944	validation_1-rmse:0.12976
# [329]	validation_0-rmse:0.04931	validation_1-rmse:0.12971
# [330]	validation_0-rmse:0.04920	validation_1-rmse:0.12971
# [331]	validation_0-rmse:0.04900	validation_1-rmse:0.12967
# [332]	validation_0-rmse:0.04891	validation_1-rmse:0.12964
# [333]	validation_0-rmse:0.04875	validation_1-rmse:0.12959
# [334]	validation_0-rmse:0.04859	validation_1-rmse:0.12956
# [335]	validation_0-rmse:0.04856	validation_1-rmse:0.12954
# [336]	validation_0-rmse:0.04851	validation_1-rmse:0.12952
# [337]	validation_0-rmse:0.04832	validation_1-rmse:0.12946
# [338]	validation_0-rmse:0.04814	validation_1-rmse:0.12944
# [339]	validation_0-rmse:0.04804	validation_1-rmse:0.12944
# [340]	validation_0-rmse:0.04787	validation_1-rmse:0.12938
# [341]	validation_0-rmse:0.04774	validation_1-rmse:0.12937
# [342]	validation_0-rmse:0.04771	validation_1-rmse:0.12936
# [343]	validation_0-rmse:0.04756	validation_1-rmse:0.12933
# [344]	validation_0-rmse:0.04741	validation_1-rmse:0.12931
# [345]	validation_0-rmse:0.04724	validation_1-rmse:0.12927
# [346]	validation_0-rmse:0.04715	validation_1-rmse:0.12925
# [347]	validation_0-rmse:0.04698	validation_1-rmse:0.12925
# [348]	validation_0-rmse:0.04691	validation_1-rmse:0.12926
# [349]	validation_0-rmse:0.04676	validation_1-rmse:0.12925
# [350]	validation_0-rmse:0.04667	validation_1-rmse:0.12924
# [351]	validation_0-rmse:0.04652	validation_1-rmse:0.12922
# [352]	validation_0-rmse:0.04641	validation_1-rmse:0.12920
# [353]	validation_0-rmse:0.04623	validation_1-rmse:0.12918
# [354]	validation_0-rmse:0.04611	validation_1-rmse:0.12918
# [355]	validation_0-rmse:0.04608	validation_1-rmse:0.12918
# [356]	validation_0-rmse:0.04602	validation_1-rmse:0.12916
# [357]	validation_0-rmse:0.04583	validation_1-rmse:0.12912
# [358]	validation_0-rmse:0.04577	validation_1-rmse:0.12914
# [359]	validation_0-rmse:0.04570	validation_1-rmse:0.12913
# [360]	validation_0-rmse:0.04555	validation_1-rmse:0.12907
# [361]	validation_0-rmse:0.04543	validation_1-rmse:0.12903
# [362]	validation_0-rmse:0.04539	validation_1-rmse:0.12903
# [363]	validation_0-rmse:0.04527	validation_1-rmse:0.12902
# [364]	validation_0-rmse:0.04515	validation_1-rmse:0.12898
# [365]	validation_0-rmse:0.04494	validation_1-rmse:0.12900
# [366]	validation_0-rmse:0.04483	validation_1-rmse:0.12896
# [367]	validation_0-rmse:0.04475	validation_1-rmse:0.12893
# [368]	validation_0-rmse:0.04473	validation_1-rmse:0.12894
# [369]	validation_0-rmse:0.04453	validation_1-rmse:0.12893
# [370]	validation_0-rmse:0.04440	validation_1-rmse:0.12892
# [371]	validation_0-rmse:0.04431	validation_1-rmse:0.12892
# [372]	validation_0-rmse:0.04416	validation_1-rmse:0.12889
# [373]	validation_0-rmse:0.04399	validation_1-rmse:0.12888
# [374]	validation_0-rmse:0.04390	validation_1-rmse:0.12885
# [375]	validation_0-rmse:0.04378	validation_1-rmse:0.12885
# [376]	validation_0-rmse:0.04372	validation_1-rmse:0.12884
# [377]	validation_0-rmse:0.04356	validation_1-rmse:0.12884
# [378]	validation_0-rmse:0.04349	validation_1-rmse:0.12884
# [379]	validation_0-rmse:0.04338	validation_1-rmse:0.12881
# [380]	validation_0-rmse:0.04332	validation_1-rmse:0.12881
# [381]	validation_0-rmse:0.04327	validation_1-rmse:0.12882
# [382]	validation_0-rmse:0.04316	validation_1-rmse:0.12881
# [383]	validation_0-rmse:0.04309	validation_1-rmse:0.12882
# [384]	validation_0-rmse:0.04306	validation_1-rmse:0.12880
# [385]	validation_0-rmse:0.04296	validation_1-rmse:0.12877
# [386]	validation_0-rmse:0.04289	validation_1-rmse:0.12878
# [387]	validation_0-rmse:0.04274	validation_1-rmse:0.12875
# [388]	validation_0-rmse:0.04266	validation_1-rmse:0.12874
# [389]	validation_0-rmse:0.04254	validation_1-rmse:0.12873
# [390]	validation_0-rmse:0.04248	validation_1-rmse:0.12872
# [391]	validation_0-rmse:0.04242	validation_1-rmse:0.12871
# [392]	validation_0-rmse:0.04229	validation_1-rmse:0.12868
# [393]	validation_0-rmse:0.04219	validation_1-rmse:0.12867
# [394]	validation_0-rmse:0.04214	validation_1-rmse:0.12865
# [395]	validation_0-rmse:0.04203	validation_1-rmse:0.12862
# [396]	validation_0-rmse:0.04191	validation_1-rmse:0.12862
# [397]	validation_0-rmse:0.04181	validation_1-rmse:0.12862
# [398]	validation_0-rmse:0.04173	validation_1-rmse:0.12864
# [399]	validation_0-rmse:0.04165	validation_1-rmse:0.12863
# [400]	validation_0-rmse:0.04157	validation_1-rmse:0.12862
# [401]	validation_0-rmse:0.04150	validation_1-rmse:0.12858
# [402]	validation_0-rmse:0.04139	validation_1-rmse:0.12854
# [403]	validation_0-rmse:0.04131	validation_1-rmse:0.12856
# [404]	validation_0-rmse:0.04121	validation_1-rmse:0.12854
# [405]	validation_0-rmse:0.04109	validation_1-rmse:0.12850
# [406]	validation_0-rmse:0.04099	validation_1-rmse:0.12852
# [407]	validation_0-rmse:0.04089	validation_1-rmse:0.12850
# [408]	validation_0-rmse:0.04081	validation_1-rmse:0.12847
# [409]	validation_0-rmse:0.04074	validation_1-rmse:0.12847
# [410]	validation_0-rmse:0.04061	validation_1-rmse:0.12846
# [411]	validation_0-rmse:0.04045	validation_1-rmse:0.12845
# [412]	validation_0-rmse:0.04038	validation_1-rmse:0.12843
# [413]	validation_0-rmse:0.04034	validation_1-rmse:0.12842
# [414]	validation_0-rmse:0.04019	validation_1-rmse:0.12839
# [415]	validation_0-rmse:0.04001	validation_1-rmse:0.12838
# [416]	validation_0-rmse:0.03995	validation_1-rmse:0.12837
# [417]	validation_0-rmse:0.03991	validation_1-rmse:0.12838
# [418]	validation_0-rmse:0.03979	validation_1-rmse:0.12835
# [419]	validation_0-rmse:0.03970	validation_1-rmse:0.12834
# [420]	validation_0-rmse:0.03959	validation_1-rmse:0.12834
# [421]	validation_0-rmse:0.03950	validation_1-rmse:0.12833
# [422]	validation_0-rmse:0.03944	validation_1-rmse:0.12832
# [423]	validation_0-rmse:0.03935	validation_1-rmse:0.12832
# [424]	validation_0-rmse:0.03923	validation_1-rmse:0.12831
# [425]	validation_0-rmse:0.03911	validation_1-rmse:0.12829
# [426]	validation_0-rmse:0.03900	validation_1-rmse:0.12830
# [427]	validation_0-rmse:0.03896	validation_1-rmse:0.12831
# [428]	validation_0-rmse:0.03882	validation_1-rmse:0.12834
# [429]	validation_0-rmse:0.03875	validation_1-rmse:0.12833
# [430]	validation_0-rmse:0.03865	validation_1-rmse:0.12832
# [431]	validation_0-rmse:0.03855	validation_1-rmse:0.12832
# [432]	validation_0-rmse:0.03849	validation_1-rmse:0.12832
# [433]	validation_0-rmse:0.03843	validation_1-rmse:0.12832
# [434]	validation_0-rmse:0.03837	validation_1-rmse:0.12833
# [435]	validation_0-rmse:0.03828	validation_1-rmse:0.12830
# [I 2021-11-16 20:28:13,588] Trial 0 finished with value: 0.12828821598611984 and parameters: {'base_score': 0.7492546989054832, 'max_depth': 12, 'n_jobs': 16, 'min_child_weight': 10, 'n_estimators': 2152, 'colsample_bytree': 0.7901313901911611, 'subsample': 0.7739265386526697, 'learning_rate': 0.0490824366951667}. Best is trial 0 with value: 0.12828821598611984.
# [20:28:13] WARNING: ..\src\learner.cc:541:
# Parameters: { enable_categorical } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-rmse:15.45938	validation_1-rmse:15.45965
# [1]	validation_0-rmse:15.21231	validation_1-rmse:15.21274
# [2]	validation_0-rmse:14.96920	validation_1-rmse:14.96987
# [3]	validation_0-rmse:14.73000	validation_1-rmse:14.73077
# [4]	validation_0-rmse:14.49469	validation_1-rmse:14.49555
# [5]	validation_0-rmse:14.26311	validation_1-rmse:14.26405
# [6]	validation_0-rmse:14.03520	validation_1-rmse:14.03628
# [7]	validation_0-rmse:13.81096	validation_1-rmse:13.81219
# [8]	validation_0-rmse:13.59033	validation_1-rmse:13.59181
# [9]	validation_0-rmse:13.37318	validation_1-rmse:13.37484
# [10]	validation_0-rmse:13.15952	validation_1-rmse:13.16141
# [11]	validation_0-rmse:12.94928	validation_1-rmse:12.95149
# [12]	validation_0-rmse:12.74239	validation_1-rmse:12.74490
# [13]	validation_0-rmse:12.53878	validation_1-rmse:12.54147
# [14]	validation_0-rmse:12.33849	validation_1-rmse:12.34127
# [15]	validation_0-rmse:12.14139	validation_1-rmse:12.14437
# [16]	validation_0-rmse:11.94746	validation_1-rmse:11.95067
# [17]	validation_0-rmse:11.75663	validation_1-rmse:11.75997
# [18]	validation_0-rmse:11.56879	validation_1-rmse:11.57238
# [19]	validation_0-rmse:11.38398	validation_1-rmse:11.38777
# [20]	validation_0-rmse:11.20216	validation_1-rmse:11.20606
# [21]	validation_0-rmse:11.02325	validation_1-rmse:11.02731
# [22]	validation_0-rmse:10.84720	validation_1-rmse:10.85138
# [23]	validation_0-rmse:10.67395	validation_1-rmse:10.67831
# [24]	validation_0-rmse:10.50343	validation_1-rmse:10.50790
# [25]	validation_0-rmse:10.33565	validation_1-rmse:10.34024
# [26]	validation_0-rmse:10.17056	validation_1-rmse:10.17532
# [27]	validation_0-rmse:10.00817	validation_1-rmse:10.01304
# [28]	validation_0-rmse:9.84833	validation_1-rmse:9.85331
# [29]	validation_0-rmse:9.69107	validation_1-rmse:9.69616
# [30]	validation_0-rmse:9.53634	validation_1-rmse:9.54166
# [31]	validation_0-rmse:9.38409	validation_1-rmse:9.38960
# [32]	validation_0-rmse:9.23427	validation_1-rmse:9.23982
# [33]	validation_0-rmse:9.08682	validation_1-rmse:9.09246
# [34]	validation_0-rmse:8.94172	validation_1-rmse:8.94742
# [35]	validation_0-rmse:8.79894	validation_1-rmse:8.80469
# [36]	validation_0-rmse:8.65845	validation_1-rmse:8.66427
# [37]	validation_0-rmse:8.52021	validation_1-rmse:8.52601
# [38]	validation_0-rmse:8.38418	validation_1-rmse:8.39006
# [39]	validation_0-rmse:8.25038	validation_1-rmse:8.25645
# [40]	validation_0-rmse:8.11872	validation_1-rmse:8.12484
# [41]	validation_0-rmse:7.98916	validation_1-rmse:7.99536
# [42]	validation_0-rmse:7.86162	validation_1-rmse:7.86796
# [43]	validation_0-rmse:7.73616	validation_1-rmse:7.74258
# [44]	validation_0-rmse:7.61268	validation_1-rmse:7.61920
# [45]	validation_0-rmse:7.49120	validation_1-rmse:7.49780
# [46]	validation_0-rmse:7.37167	validation_1-rmse:7.37835
# [47]	validation_0-rmse:7.25406	validation_1-rmse:7.26084
# [48]	validation_0-rmse:7.13829	validation_1-rmse:7.14520
# [49]	validation_0-rmse:7.02435	validation_1-rmse:7.03140
# [50]	validation_0-rmse:6.91227	validation_1-rmse:6.91943
# [51]	validation_0-rmse:6.80200	validation_1-rmse:6.80930
# [52]	validation_0-rmse:6.69351	validation_1-rmse:6.70092
# [53]	validation_0-rmse:6.58675	validation_1-rmse:6.59419
# [54]	validation_0-rmse:6.48165	validation_1-rmse:6.48923
# [55]	validation_0-rmse:6.37827	validation_1-rmse:6.38588
# [56]	validation_0-rmse:6.27653	validation_1-rmse:6.28422
# [57]	validation_0-rmse:6.17642	validation_1-rmse:6.18424
# [58]	validation_0-rmse:6.07791	validation_1-rmse:6.08573
# [59]	validation_0-rmse:5.98096	validation_1-rmse:5.98882
# [60]	validation_0-rmse:5.88556	validation_1-rmse:5.89350
# [61]	validation_0-rmse:5.79174	validation_1-rmse:5.79978
# [62]	validation_0-rmse:5.69940	validation_1-rmse:5.70749
# [63]	validation_0-rmse:5.60852	validation_1-rmse:5.61667
# [64]	validation_0-rmse:5.51911	validation_1-rmse:5.52735
# [65]	validation_0-rmse:5.43118	validation_1-rmse:5.43957
# [66]	validation_0-rmse:5.34459	validation_1-rmse:5.35299
# [67]	validation_0-rmse:5.25938	validation_1-rmse:5.26779
# [68]	validation_0-rmse:5.17553	validation_1-rmse:5.18401
# [69]	validation_0-rmse:5.09306	validation_1-rmse:5.10152
# [70]	validation_0-rmse:5.01192	validation_1-rmse:5.02043
# [71]	validation_0-rmse:4.93205	validation_1-rmse:4.94064
# [72]	validation_0-rmse:4.85348	validation_1-rmse:4.86207
# [73]	validation_0-rmse:4.77617	validation_1-rmse:4.78482
# [74]	validation_0-rmse:4.70007	validation_1-rmse:4.70876
# [75]	validation_0-rmse:4.62521	validation_1-rmse:4.63400
# [76]	validation_0-rmse:4.55153	validation_1-rmse:4.56033
# [77]	validation_0-rmse:4.47907	validation_1-rmse:4.48795
# [78]	validation_0-rmse:4.40770	validation_1-rmse:4.41658
# [79]	validation_0-rmse:4.33749	validation_1-rmse:4.34637
# [80]	validation_0-rmse:4.26846	validation_1-rmse:4.27742
# [81]	validation_0-rmse:4.20051	validation_1-rmse:4.20948
# [82]	validation_0-rmse:4.13363	validation_1-rmse:4.14262
# [83]	validation_0-rmse:4.06781	validation_1-rmse:4.07673
# [84]	validation_0-rmse:4.00308	validation_1-rmse:4.01201
# [85]	validation_0-rmse:3.93937	validation_1-rmse:3.94837
# [86]	validation_0-rmse:3.87668	validation_1-rmse:3.88567
# [87]	validation_0-rmse:3.81502	validation_1-rmse:3.82407
# [88]	validation_0-rmse:3.75433	validation_1-rmse:3.76340
# [89]	validation_0-rmse:3.69460	validation_1-rmse:3.70366
# [90]	validation_0-rmse:3.63582	validation_1-rmse:3.64487
# [91]	validation_0-rmse:3.57798	validation_1-rmse:3.58717
# [92]	validation_0-rmse:3.52109	validation_1-rmse:3.53028
# [93]	validation_0-rmse:3.46508	validation_1-rmse:3.47433
# [94]	validation_0-rmse:3.40998	validation_1-rmse:3.41931
# [95]	validation_0-rmse:3.35578	validation_1-rmse:3.36510
# [96]	validation_0-rmse:3.30245	validation_1-rmse:3.31192
# [97]	validation_0-rmse:3.24999	validation_1-rmse:3.25951
# [98]	validation_0-rmse:3.19834	validation_1-rmse:3.20786
# [99]	validation_0-rmse:3.14757	validation_1-rmse:3.15713
# [100]	validation_0-rmse:3.09761	validation_1-rmse:3.10721
# [101]	validation_0-rmse:3.04841	validation_1-rmse:3.05800
# [102]	validation_0-rmse:3.00002	validation_1-rmse:3.00962
# [103]	validation_0-rmse:2.95237	validation_1-rmse:2.96196
# [104]	validation_0-rmse:2.90552	validation_1-rmse:2.91510
# [105]	validation_0-rmse:2.85941	validation_1-rmse:2.86905
# [106]	validation_0-rmse:2.81406	validation_1-rmse:2.82367
# [107]	validation_0-rmse:2.76942	validation_1-rmse:2.77894
# [108]	validation_0-rmse:2.72548	validation_1-rmse:2.73508
# [109]	validation_0-rmse:2.68226	validation_1-rmse:2.69195
# [110]	validation_0-rmse:2.63975	validation_1-rmse:2.64943
# [111]	validation_0-rmse:2.59791	validation_1-rmse:2.60763
# [112]	validation_0-rmse:2.55672	validation_1-rmse:2.56651
# [113]	validation_0-rmse:2.51619	validation_1-rmse:2.52597
# [114]	validation_0-rmse:2.47634	validation_1-rmse:2.48616
# [115]	validation_0-rmse:2.43714	validation_1-rmse:2.44698
# [116]	validation_0-rmse:2.39856	validation_1-rmse:2.40841
# [117]	validation_0-rmse:2.36057	validation_1-rmse:2.37037
# [118]	validation_0-rmse:2.32322	validation_1-rmse:2.33302
# [119]	validation_0-rmse:2.28645	validation_1-rmse:2.29627
# [120]	validation_0-rmse:2.25026	validation_1-rmse:2.26009
# [121]	validation_0-rmse:2.21466	validation_1-rmse:2.22457
# [122]	validation_0-rmse:2.17960	validation_1-rmse:2.18953
# [123]	validation_0-rmse:2.14511	validation_1-rmse:2.15511
# [124]	validation_0-rmse:2.11118	validation_1-rmse:2.12119
# [125]	validation_0-rmse:2.07783	validation_1-rmse:2.08781
# [126]	validation_0-rmse:2.04503	validation_1-rmse:2.05500
# [127]	validation_0-rmse:2.01272	validation_1-rmse:2.02271
# [128]	validation_0-rmse:1.98094	validation_1-rmse:1.99094
# [129]	validation_0-rmse:1.94968	validation_1-rmse:1.95970
# [130]	validation_0-rmse:1.91889	validation_1-rmse:1.92888
# [131]	validation_0-rmse:1.88860	validation_1-rmse:1.89863
# [132]	validation_0-rmse:1.85882	validation_1-rmse:1.86893
# [133]	validation_0-rmse:1.82951	validation_1-rmse:1.83963
# [134]	validation_0-rmse:1.80070	validation_1-rmse:1.81092
# [135]	validation_0-rmse:1.77235	validation_1-rmse:1.78255
# [136]	validation_0-rmse:1.74445	validation_1-rmse:1.75463
# [137]	validation_0-rmse:1.71697	validation_1-rmse:1.72718
# [138]	validation_0-rmse:1.68992	validation_1-rmse:1.70023
# [139]	validation_0-rmse:1.66336	validation_1-rmse:1.67370
# [140]	validation_0-rmse:1.63721	validation_1-rmse:1.64754
# [141]	validation_0-rmse:1.61150	validation_1-rmse:1.62184
# [142]	validation_0-rmse:1.58617	validation_1-rmse:1.59650
# [143]	validation_0-rmse:1.56129	validation_1-rmse:1.57168
# [144]	validation_0-rmse:1.53679	validation_1-rmse:1.54719
# [145]	validation_0-rmse:1.51268	validation_1-rmse:1.52312
# [146]	validation_0-rmse:1.48896	validation_1-rmse:1.49937
# [147]	validation_0-rmse:1.46559	validation_1-rmse:1.47603
# [148]	validation_0-rmse:1.44265	validation_1-rmse:1.45306
# [149]	validation_0-rmse:1.42005	validation_1-rmse:1.43044
# [150]	validation_0-rmse:1.39783	validation_1-rmse:1.40826
# [151]	validation_0-rmse:1.37596	validation_1-rmse:1.38638
# [152]	validation_0-rmse:1.35444	validation_1-rmse:1.36486
# [153]	validation_0-rmse:1.33329	validation_1-rmse:1.34375
# [154]	validation_0-rmse:1.31246	validation_1-rmse:1.32292
# [155]	validation_0-rmse:1.29198	validation_1-rmse:1.30242
# [156]	validation_0-rmse:1.27182	validation_1-rmse:1.28224
# [157]	validation_0-rmse:1.25201	validation_1-rmse:1.26247
# [158]	validation_0-rmse:1.23250	validation_1-rmse:1.24301
# [159]	validation_0-rmse:1.21331	validation_1-rmse:1.22382
# [160]	validation_0-rmse:1.19445	validation_1-rmse:1.20504
# [161]	validation_0-rmse:1.17588	validation_1-rmse:1.18649
# [162]	validation_0-rmse:1.15758	validation_1-rmse:1.16833
# [163]	validation_0-rmse:1.13958	validation_1-rmse:1.15036
# [164]	validation_0-rmse:1.12190	validation_1-rmse:1.13271
# [165]	validation_0-rmse:1.10451	validation_1-rmse:1.11539
# [166]	validation_0-rmse:1.08738	validation_1-rmse:1.09824
# [167]	validation_0-rmse:1.07055	validation_1-rmse:1.08143
# [168]	validation_0-rmse:1.05398	validation_1-rmse:1.06492
# [169]	validation_0-rmse:1.03765	validation_1-rmse:1.04862
# [170]	validation_0-rmse:1.02165	validation_1-rmse:1.03263
# [171]	validation_0-rmse:1.00585	validation_1-rmse:1.01676
# [172]	validation_0-rmse:0.99035	validation_1-rmse:1.00127
# [173]	validation_0-rmse:0.97511	validation_1-rmse:0.98604
# [174]	validation_0-rmse:0.96011	validation_1-rmse:0.97107
# [175]	validation_0-rmse:0.94532	validation_1-rmse:0.95631
# [176]	validation_0-rmse:0.93080	validation_1-rmse:0.94187
# [177]	validation_0-rmse:0.91653	validation_1-rmse:0.92767
# [178]	validation_0-rmse:0.90249	validation_1-rmse:0.91371
# [179]	validation_0-rmse:0.88863	validation_1-rmse:0.89995
# [180]	validation_0-rmse:0.87503	validation_1-rmse:0.88640
# [181]	validation_0-rmse:0.86165	validation_1-rmse:0.87303
# [182]	validation_0-rmse:0.84846	validation_1-rmse:0.85983
# [183]	validation_0-rmse:0.83549	validation_1-rmse:0.84691
# [184]	validation_0-rmse:0.82275	validation_1-rmse:0.83417
# [185]	validation_0-rmse:0.81023	validation_1-rmse:0.82166
# [186]	validation_0-rmse:0.79789	validation_1-rmse:0.80936
# [187]	validation_0-rmse:0.78577	validation_1-rmse:0.79718
# [188]	validation_0-rmse:0.77383	validation_1-rmse:0.78528
# [189]	validation_0-rmse:0.76211	validation_1-rmse:0.77356
# [190]	validation_0-rmse:0.75054	validation_1-rmse:0.76205
# [191]	validation_0-rmse:0.73916	validation_1-rmse:0.75071
# [192]	validation_0-rmse:0.72799	validation_1-rmse:0.73963
# [193]	validation_0-rmse:0.71698	validation_1-rmse:0.72867
# [194]	validation_0-rmse:0.70617	validation_1-rmse:0.71785
# [195]	validation_0-rmse:0.69555	validation_1-rmse:0.70735
# [196]	validation_0-rmse:0.68510	validation_1-rmse:0.69696
# [197]	validation_0-rmse:0.67478	validation_1-rmse:0.68673
# [198]	validation_0-rmse:0.66462	validation_1-rmse:0.67661
# [199]	validation_0-rmse:0.65462	validation_1-rmse:0.66672
# [200]	validation_0-rmse:0.64485	validation_1-rmse:0.65702
# [201]	validation_0-rmse:0.63519	validation_1-rmse:0.64747
# [202]	validation_0-rmse:0.62570	validation_1-rmse:0.63804
# [203]	validation_0-rmse:0.61638	validation_1-rmse:0.62874
# [204]	validation_0-rmse:0.60722	validation_1-rmse:0.61971
# [205]	validation_0-rmse:0.59818	validation_1-rmse:0.61068
# [206]	validation_0-rmse:0.58928	validation_1-rmse:0.60185
# [207]	validation_0-rmse:0.58057	validation_1-rmse:0.59322
# [208]	validation_0-rmse:0.57201	validation_1-rmse:0.58472
# [209]	validation_0-rmse:0.56357	validation_1-rmse:0.57643
# [210]	validation_0-rmse:0.55530	validation_1-rmse:0.56819
# [211]	validation_0-rmse:0.54709	validation_1-rmse:0.56002
# [212]	validation_0-rmse:0.53905	validation_1-rmse:0.55204
# [213]	validation_0-rmse:0.53118	validation_1-rmse:0.54427
# [214]	validation_0-rmse:0.52341	validation_1-rmse:0.53659
# [215]	validation_0-rmse:0.51582	validation_1-rmse:0.52906
# [216]	validation_0-rmse:0.50831	validation_1-rmse:0.52164
# [217]	validation_0-rmse:0.50095	validation_1-rmse:0.51438
# [218]	validation_0-rmse:0.49370	validation_1-rmse:0.50724
# [219]	validation_0-rmse:0.48655	validation_1-rmse:0.50023
# [220]	validation_0-rmse:0.47955	validation_1-rmse:0.49334
# [221]	validation_0-rmse:0.47267	validation_1-rmse:0.48658
# [222]	validation_0-rmse:0.46590	validation_1-rmse:0.48000
# [223]	validation_0-rmse:0.45926	validation_1-rmse:0.47345
# [224]	validation_0-rmse:0.45269	validation_1-rmse:0.46704
# [225]	validation_0-rmse:0.44623	validation_1-rmse:0.46066
# [226]	validation_0-rmse:0.43987	validation_1-rmse:0.45440
# [227]	validation_0-rmse:0.43365	validation_1-rmse:0.44832
# [228]	validation_0-rmse:0.42750	validation_1-rmse:0.44236
# [229]	validation_0-rmse:0.42146	validation_1-rmse:0.43648
# [230]	validation_0-rmse:0.41554	validation_1-rmse:0.43070
# [231]	validation_0-rmse:0.40971	validation_1-rmse:0.42495
# [232]	validation_0-rmse:0.40399	validation_1-rmse:0.41938
# [233]	validation_0-rmse:0.39833	validation_1-rmse:0.41384
# [234]	validation_0-rmse:0.39280	validation_1-rmse:0.40844
# [235]	validation_0-rmse:0.38738	validation_1-rmse:0.40320
# [236]	validation_0-rmse:0.38207	validation_1-rmse:0.39795
# [237]	validation_0-rmse:0.37682	validation_1-rmse:0.39278
# [238]	validation_0-rmse:0.37167	validation_1-rmse:0.38770
# [239]	validation_0-rmse:0.36659	validation_1-rmse:0.38274
# [240]	validation_0-rmse:0.36159	validation_1-rmse:0.37789
# [241]	validation_0-rmse:0.35666	validation_1-rmse:0.37305
# [242]	validation_0-rmse:0.35185	validation_1-rmse:0.36837
# [243]	validation_0-rmse:0.34711	validation_1-rmse:0.36380
# [244]	validation_0-rmse:0.34246	validation_1-rmse:0.35930
# [245]	validation_0-rmse:0.33791	validation_1-rmse:0.35492
# [246]	validation_0-rmse:0.33344	validation_1-rmse:0.35062
# [247]	validation_0-rmse:0.32900	validation_1-rmse:0.34629
# [248]	validation_0-rmse:0.32470	validation_1-rmse:0.34216
# [249]	validation_0-rmse:0.32043	validation_1-rmse:0.33802
# [250]	validation_0-rmse:0.31625	validation_1-rmse:0.33404
# [251]	validation_0-rmse:0.31211	validation_1-rmse:0.33012
# [252]	validation_0-rmse:0.30809	validation_1-rmse:0.32627
# [253]	validation_0-rmse:0.30416	validation_1-rmse:0.32252
# [254]	validation_0-rmse:0.30029	validation_1-rmse:0.31880
# [255]	validation_0-rmse:0.29646	validation_1-rmse:0.31514
# [256]	validation_0-rmse:0.29270	validation_1-rmse:0.31159
# [257]	validation_0-rmse:0.28903	validation_1-rmse:0.30807
# [258]	validation_0-rmse:0.28538	validation_1-rmse:0.30467
# [259]	validation_0-rmse:0.28183	validation_1-rmse:0.30129
# [260]	validation_0-rmse:0.27832	validation_1-rmse:0.29793
# [261]	validation_0-rmse:0.27490	validation_1-rmse:0.29471
# [262]	validation_0-rmse:0.27154	validation_1-rmse:0.29150
# [263]	validation_0-rmse:0.26823	validation_1-rmse:0.28832
# [264]	validation_0-rmse:0.26498	validation_1-rmse:0.28523
# [265]	validation_0-rmse:0.26176	validation_1-rmse:0.28214
# [266]	validation_0-rmse:0.25864	validation_1-rmse:0.27919
# [267]	validation_0-rmse:0.25558	validation_1-rmse:0.27631
# [268]	validation_0-rmse:0.25256	validation_1-rmse:0.27347
# [269]	validation_0-rmse:0.24958	validation_1-rmse:0.27064
# [270]	validation_0-rmse:0.24665	validation_1-rmse:0.26786
# [271]	validation_0-rmse:0.24377	validation_1-rmse:0.26517
# [272]	validation_0-rmse:0.24094	validation_1-rmse:0.26253
# [273]	validation_0-rmse:0.23818	validation_1-rmse:0.25992
# [274]	validation_0-rmse:0.23543	validation_1-rmse:0.25737
# [275]	validation_0-rmse:0.23276	validation_1-rmse:0.25499
# [276]	validation_0-rmse:0.23011	validation_1-rmse:0.25258
# [277]	validation_0-rmse:0.22753	validation_1-rmse:0.25013
# [278]	validation_0-rmse:0.22505	validation_1-rmse:0.24781
# [279]	validation_0-rmse:0.22260	validation_1-rmse:0.24553
# [280]	validation_0-rmse:0.22017	validation_1-rmse:0.24326
# [281]	validation_0-rmse:0.21777	validation_1-rmse:0.24105
# [282]	validation_0-rmse:0.21541	validation_1-rmse:0.23886
# [283]	validation_0-rmse:0.21315	validation_1-rmse:0.23679
# [284]	validation_0-rmse:0.21094	validation_1-rmse:0.23474
# [285]	validation_0-rmse:0.20872	validation_1-rmse:0.23266
# [286]	validation_0-rmse:0.20650	validation_1-rmse:0.23068
# [287]	validation_0-rmse:0.20441	validation_1-rmse:0.22879
# [288]	validation_0-rmse:0.20232	validation_1-rmse:0.22690
# [289]	validation_0-rmse:0.20025	validation_1-rmse:0.22502
# [290]	validation_0-rmse:0.19827	validation_1-rmse:0.22327
# [291]	validation_0-rmse:0.19633	validation_1-rmse:0.22154
# [292]	validation_0-rmse:0.19438	validation_1-rmse:0.21983
# [293]	validation_0-rmse:0.19250	validation_1-rmse:0.21812
# [294]	validation_0-rmse:0.19067	validation_1-rmse:0.21649
# [295]	validation_0-rmse:0.18886	validation_1-rmse:0.21494
# [296]	validation_0-rmse:0.18709	validation_1-rmse:0.21335
# [297]	validation_0-rmse:0.18531	validation_1-rmse:0.21178
# [298]	validation_0-rmse:0.18365	validation_1-rmse:0.21033
# [299]	validation_0-rmse:0.18194	validation_1-rmse:0.20885
# [300]	validation_0-rmse:0.18025	validation_1-rmse:0.20742
# [301]	validation_0-rmse:0.17862	validation_1-rmse:0.20601
# [302]	validation_0-rmse:0.17701	validation_1-rmse:0.20458
# [303]	validation_0-rmse:0.17543	validation_1-rmse:0.20322
# [304]	validation_0-rmse:0.17395	validation_1-rmse:0.20191
# [305]	validation_0-rmse:0.17242	validation_1-rmse:0.20058
# [306]	validation_0-rmse:0.17090	validation_1-rmse:0.19926
# [307]	validation_0-rmse:0.16944	validation_1-rmse:0.19802
# [308]	validation_0-rmse:0.16805	validation_1-rmse:0.19685
# [309]	validation_0-rmse:0.16670	validation_1-rmse:0.19570
# [310]	validation_0-rmse:0.16533	validation_1-rmse:0.19453
# [311]	validation_0-rmse:0.16401	validation_1-rmse:0.19335
# [312]	validation_0-rmse:0.16270	validation_1-rmse:0.19221
# [313]	validation_0-rmse:0.16145	validation_1-rmse:0.19110
# [314]	validation_0-rmse:0.16022	validation_1-rmse:0.19008
# [315]	validation_0-rmse:0.15901	validation_1-rmse:0.18901
# [316]	validation_0-rmse:0.15784	validation_1-rmse:0.18803
# [317]	validation_0-rmse:0.15670	validation_1-rmse:0.18707
# [318]	validation_0-rmse:0.15558	validation_1-rmse:0.18608
# [319]	validation_0-rmse:0.15443	validation_1-rmse:0.18507
# [320]	validation_0-rmse:0.15330	validation_1-rmse:0.18415
# [321]	validation_0-rmse:0.15224	validation_1-rmse:0.18323
# [322]	validation_0-rmse:0.15116	validation_1-rmse:0.18232
# [323]	validation_0-rmse:0.15008	validation_1-rmse:0.18144
# [324]	validation_0-rmse:0.14905	validation_1-rmse:0.18056
# [325]	validation_0-rmse:0.14805	validation_1-rmse:0.17977
# [326]	validation_0-rmse:0.14701	validation_1-rmse:0.17885
# [327]	validation_0-rmse:0.14604	validation_1-rmse:0.17809
# [328]	validation_0-rmse:0.14512	validation_1-rmse:0.17736
# [329]	validation_0-rmse:0.14418	validation_1-rmse:0.17659
# [330]	validation_0-rmse:0.14335	validation_1-rmse:0.17585
# [331]	validation_0-rmse:0.14249	validation_1-rmse:0.17516
# [332]	validation_0-rmse:0.14167	validation_1-rmse:0.17450
# [333]	validation_0-rmse:0.14081	validation_1-rmse:0.17380
# [334]	validation_0-rmse:0.13993	validation_1-rmse:0.17308
# [335]	validation_0-rmse:0.13909	validation_1-rmse:0.17240
# [336]	validation_0-rmse:0.13825	validation_1-rmse:0.17167
# [337]	validation_0-rmse:0.13740	validation_1-rmse:0.17096
# [338]	validation_0-rmse:0.13662	validation_1-rmse:0.17033
# [339]	validation_0-rmse:0.13591	validation_1-rmse:0.16978
# [340]	validation_0-rmse:0.13516	validation_1-rmse:0.16923
# [341]	validation_0-rmse:0.13444	validation_1-rmse:0.16865
# [342]	validation_0-rmse:0.13371	validation_1-rmse:0.16803
# [343]	validation_0-rmse:0.13299	validation_1-rmse:0.16744
# [344]	validation_0-rmse:0.13231	validation_1-rmse:0.16688
# [345]	validation_0-rmse:0.13163	validation_1-rmse:0.16636
# [346]	validation_0-rmse:0.13094	validation_1-rmse:0.16583
# [347]	validation_0-rmse:0.13031	validation_1-rmse:0.16543
# [348]	validation_0-rmse:0.12967	validation_1-rmse:0.16491
# [349]	validation_0-rmse:0.12903	validation_1-rmse:0.16444
# [350]	validation_0-rmse:0.12841	validation_1-rmse:0.16395
# [351]	validation_0-rmse:0.12776	validation_1-rmse:0.16344
# [352]	validation_0-rmse:0.12723	validation_1-rmse:0.16302
# [353]	validation_0-rmse:0.12666	validation_1-rmse:0.16262
# [354]	validation_0-rmse:0.12607	validation_1-rmse:0.16214
# [355]	validation_0-rmse:0.12553	validation_1-rmse:0.16171
# [356]	validation_0-rmse:0.12498	validation_1-rmse:0.16127
# [357]	validation_0-rmse:0.12446	validation_1-rmse:0.16088
# [358]	validation_0-rmse:0.12397	validation_1-rmse:0.16055
# [359]	validation_0-rmse:0.12345	validation_1-rmse:0.16011
# [360]	validation_0-rmse:0.12292	validation_1-rmse:0.15968
# ...
# [757]	validation_0-rmse:0.03954	validation_1-rmse:0.12724
# [758]	validation_0-rmse:0.03948	validation_1-rmse:0.12723
# [759]	validation_0-rmse:0.03946	validation_1-rmse:0.12723
# [760]	validation_0-rmse:0.03941	validation_1-rmse:0.12721
# [761]	validation_0-rmse:0.03936	validation_1-rmse:0.12722
# [762]	validation_0-rmse:0.03933	validation_1-rmse:0.12723
# [763]	validation_0-rmse:0.03924	validation_1-rmse:0.12722
# [764]	validation_0-rmse:0.03918	validation_1-rmse:0.12720
# [765]	validation_0-rmse:0.03914	validation_1-rmse:0.12718
# [766]	validation_0-rmse:0.03911	validation_1-rmse:0.12717
# [767]	validation_0-rmse:0.03905	validation_1-rmse:0.12717
# [768]	validation_0-rmse:0.03900	validation_1-rmse:0.12716
# [769]	validation_0-rmse:0.03896	validation_1-rmse:0.12717
# [770]	validation_0-rmse:0.03894	validation_1-rmse:0.12717
# [771]	validation_0-rmse:0.03883	validation_1-rmse:0.12715
# [772]	validation_0-rmse:0.03881	validation_1-rmse:0.12715
# [773]	validation_0-rmse:0.03877	validation_1-rmse:0.12714
# [774]	validation_0-rmse:0.03870	validation_1-rmse:0.12712
# [775]	validation_0-rmse:0.03866	validation_1-rmse:0.12711
# [776]	validation_0-rmse:0.03861	validation_1-rmse:0.12710
# [777]	validation_0-rmse:0.03854	validation_1-rmse:0.12708
# [778]	validation_0-rmse:0.03852	validation_1-rmse:0.12707
# [779]	validation_0-rmse:0.03846	validation_1-rmse:0.12707
# [780]	validation_0-rmse:0.03844	validation_1-rmse:0.12707
# [781]	validation_0-rmse:0.03839	validation_1-rmse:0.12707
# [782]	validation_0-rmse:0.03831	validation_1-rmse:0.12708
# [783]	validation_0-rmse:0.03830	validation_1-rmse:0.12708
# [784]	validation_0-rmse:0.03827	validation_1-rmse:0.12707
# [785]	validation_0-rmse:0.03817	validation_1-rmse:0.12707
# [786]	validation_0-rmse:0.03812	validation_1-rmse:0.12706
# [787]	validation_0-rmse:0.03808	validation_1-rmse:0.12705
# [788]	validation_0-rmse:0.03803	validation_1-rmse:0.12704
# [789]	validation_0-rmse:0.03800	validation_1-rmse:0.12704
# [790]	validation_0-rmse:0.03795	validation_1-rmse:0.12702
# [791]	validation_0-rmse:0.03790	validation_1-rmse:0.12702
# [792]	validation_0-rmse:0.03786	validation_1-rmse:0.12701
# [793]	validation_0-rmse:0.03780	validation_1-rmse:0.12700
# [794]	validation_0-rmse:0.03775	validation_1-rmse:0.12700
# [795]	validation_0-rmse:0.03770	validation_1-rmse:0.12699
# [796]	validation_0-rmse:0.03764	validation_1-rmse:0.12699
# [797]	validation_0-rmse:0.03760	validation_1-rmse:0.12699
# [798]	validation_0-rmse:0.03755	validation_1-rmse:0.12698
# [799]	validation_0-rmse:0.03753	validation_1-rmse:0.12698
# [800]	validation_0-rmse:0.03744	validation_1-rmse:0.12695
# [801]	validation_0-rmse:0.03740	validation_1-rmse:0.12692
# [802]	validation_0-rmse:0.03736	validation_1-rmse:0.12692
# [803]	validation_0-rmse:0.03731	validation_1-rmse:0.12692
# [804]	validation_0-rmse:0.03726	validation_1-rmse:0.12692
# [805]	validation_0-rmse:0.03721	validation_1-rmse:0.12691
# [806]	validation_0-rmse:0.03715	validation_1-rmse:0.12689
# [807]	validation_0-rmse:0.03712	validation_1-rmse:0.12688
# [808]	validation_0-rmse:0.03710	validation_1-rmse:0.12689
# [809]	validation_0-rmse:0.03703	validation_1-rmse:0.12689
# [810]	validation_0-rmse:0.03700	validation_1-rmse:0.12688
# [811]	validation_0-rmse:0.03696	validation_1-rmse:0.12688
# [812]	validation_0-rmse:0.03689	validation_1-rmse:0.12687
# [813]	validation_0-rmse:0.03676	validation_1-rmse:0.12684
# [814]	validation_0-rmse:0.03671	validation_1-rmse:0.12683
# [815]	validation_0-rmse:0.03668	validation_1-rmse:0.12682
# [816]	validation_0-rmse:0.03662	validation_1-rmse:0.12682
# [817]	validation_0-rmse:0.03656	validation_1-rmse:0.12682
# [818]	validation_0-rmse:0.03653	validation_1-rmse:0.12682
# [819]	validation_0-rmse:0.03649	validation_1-rmse:0.12681
# [820]	validation_0-rmse:0.03645	validation_1-rmse:0.12681
# [821]	validation_0-rmse:0.03638	validation_1-rmse:0.12679
# [822]	validation_0-rmse:0.03634	validation_1-rmse:0.12678
# [823]	validation_0-rmse:0.03629	validation_1-rmse:0.12676
# [824]	validation_0-rmse:0.03625	validation_1-rmse:0.12676
# [825]	validation_0-rmse:0.03622	validation_1-rmse:0.12676
# [826]	validation_0-rmse:0.03619	validation_1-rmse:0.12676
# [827]	validation_0-rmse:0.03612	validation_1-rmse:0.12675
# [828]	validation_0-rmse:0.03608	validation_1-rmse:0.12675
# [829]	validation_0-rmse:0.03607	validation_1-rmse:0.12675
# [830]	validation_0-rmse:0.03601	validation_1-rmse:0.12675
# [831]	validation_0-rmse:0.03599	validation_1-rmse:0.12675
# [832]	validation_0-rmse:0.03596	validation_1-rmse:0.12675
# [833]	validation_0-rmse:0.03590	validation_1-rmse:0.12675
# [834]	validation_0-rmse:0.03584	validation_1-rmse:0.12674
# [835]	validation_0-rmse:0.03580	validation_1-rmse:0.12675
# [836]	validation_0-rmse:0.03576	validation_1-rmse:0.12673
# [837]	validation_0-rmse:0.03574	validation_1-rmse:0.12673
# [838]	validation_0-rmse:0.03568	validation_1-rmse:0.12673
# [839]	validation_0-rmse:0.03562	validation_1-rmse:0.12673
# [840]	validation_0-rmse:0.03560	validation_1-rmse:0.12674
# [841]	validation_0-rmse:0.03556	validation_1-rmse:0.12675
# [842]	validation_0-rmse:0.03549	validation_1-rmse:0.12674
# [843]	validation_0-rmse:0.03545	validation_1-rmse:0.12673
# [844]	validation_0-rmse:0.03542	validation_1-rmse:0.12672
# [845]	validation_0-rmse:0.03540	validation_1-rmse:0.12671
# [846]	validation_0-rmse:0.03537	validation_1-rmse:0.12672
# [847]	validation_0-rmse:0.03534	validation_1-rmse:0.12673
# [848]	validation_0-rmse:0.03531	validation_1-rmse:0.12673
# [849]	validation_0-rmse:0.03526	validation_1-rmse:0.12672
# [850]	validation_0-rmse:0.03522	validation_1-rmse:0.12672
# [851]	validation_0-rmse:0.03518	validation_1-rmse:0.12671
# [852]	validation_0-rmse:0.03512	validation_1-rmse:0.12669
# [853]	validation_0-rmse:0.03509	validation_1-rmse:0.12669
# [854]	validation_0-rmse:0.03506	validation_1-rmse:0.12669
# [855]	validation_0-rmse:0.03501	validation_1-rmse:0.12668
# [856]	validation_0-rmse:0.03495	validation_1-rmse:0.12669
# [857]	validation_0-rmse:0.03493	validation_1-rmse:0.12669
# [858]	validation_0-rmse:0.03488	validation_1-rmse:0.12669
# [859]	validation_0-rmse:0.03484	validation_1-rmse:0.12668
# [860]	validation_0-rmse:0.03479	validation_1-rmse:0.12667
# [861]	validation_0-rmse:0.03476	validation_1-rmse:0.12667
# [862]	validation_0-rmse:0.03473	validation_1-rmse:0.12665
# [863]	validation_0-rmse:0.03469	validation_1-rmse:0.12664
# [864]	validation_0-rmse:0.03465	validation_1-rmse:0.12663
# [865]	validation_0-rmse:0.03460	validation_1-rmse:0.12662
# [866]	validation_0-rmse:0.03456	validation_1-rmse:0.12662
# [867]	validation_0-rmse:0.03451	validation_1-rmse:0.12663
# [868]	validation_0-rmse:0.03446	validation_1-rmse:0.12662
# [869]	validation_0-rmse:0.03444	validation_1-rmse:0.12662
# [870]	validation_0-rmse:0.03440	validation_1-rmse:0.12662
# [871]	validation_0-rmse:0.03437	validation_1-rmse:0.12662
# [872]	validation_0-rmse:0.03432	validation_1-rmse:0.12662
# [873]	validation_0-rmse:0.03428	validation_1-rmse:0.12662
# [874]	validation_0-rmse:0.03424	validation_1-rmse:0.12660
# [875]	validation_0-rmse:0.03419	validation_1-rmse:0.12658
# [876]	validation_0-rmse:0.03415	validation_1-rmse:0.12657
# [877]	validation_0-rmse:0.03409	validation_1-rmse:0.12656
# [878]	validation_0-rmse:0.03404	validation_1-rmse:0.12657
# [879]	validation_0-rmse:0.03401	validation_1-rmse:0.12656
# [880]	validation_0-rmse:0.03395	validation_1-rmse:0.12655
# [881]	validation_0-rmse:0.03393	validation_1-rmse:0.12655
# [882]	validation_0-rmse:0.03387	validation_1-rmse:0.12655
# [883]	validation_0-rmse:0.03385	validation_1-rmse:0.12655
# [884]	validation_0-rmse:0.03381	validation_1-rmse:0.12654
# [885]	validation_0-rmse:0.03378	validation_1-rmse:0.12653
# [886]	validation_0-rmse:0.03373	validation_1-rmse:0.12652
# [887]	validation_0-rmse:0.03370	validation_1-rmse:0.12652
# [888]	validation_0-rmse:0.03367	validation_1-rmse:0.12653
# [889]	validation_0-rmse:0.03363	validation_1-rmse:0.12652
# [890]	validation_0-rmse:0.03357	validation_1-rmse:0.12652
# [891]	validation_0-rmse:0.03348	validation_1-rmse:0.12651
# [892]	validation_0-rmse:0.03345	validation_1-rmse:0.12651
# [893]	validation_0-rmse:0.03338	validation_1-rmse:0.12651
# [894]	validation_0-rmse:0.03336	validation_1-rmse:0.12650
# [895]	validation_0-rmse:0.03333	validation_1-rmse:0.12649
# [896]	validation_0-rmse:0.03329	validation_1-rmse:0.12650
# [897]	validation_0-rmse:0.03326	validation_1-rmse:0.12650
# [898]	validation_0-rmse:0.03320	validation_1-rmse:0.12650
# [899]	validation_0-rmse:0.03318	validation_1-rmse:0.12649
# [900]	validation_0-rmse:0.03311	validation_1-rmse:0.12649
# [901]	validation_0-rmse:0.03307	validation_1-rmse:0.12648
# [902]	validation_0-rmse:0.03303	validation_1-rmse:0.12648
# [903]	validation_0-rmse:0.03301	validation_1-rmse:0.12648
# [904]	validation_0-rmse:0.03297	validation_1-rmse:0.12648
# [905]	validation_0-rmse:0.03295	validation_1-rmse:0.12648
# [906]	validation_0-rmse:0.03291	validation_1-rmse:0.12648
# [907]	validation_0-rmse:0.03287	validation_1-rmse:0.12647
# [908]	validation_0-rmse:0.03278	validation_1-rmse:0.12646
# [909]	validation_0-rmse:0.03271	validation_1-rmse:0.12646
# [910]	validation_0-rmse:0.03266	validation_1-rmse:0.12646
# [911]	validation_0-rmse:0.03261	validation_1-rmse:0.12646
# [912]	validation_0-rmse:0.03256	validation_1-rmse:0.12646
# [913]	validation_0-rmse:0.03252	validation_1-rmse:0.12646
# [914]	validation_0-rmse:0.03249	validation_1-rmse:0.12645
# [915]	validation_0-rmse:0.03247	validation_1-rmse:0.12645
# [916]	validation_0-rmse:0.03245	validation_1-rmse:0.12645
# [917]	validation_0-rmse:0.03241	validation_1-rmse:0.12644
# [918]	validation_0-rmse:0.03236	validation_1-rmse:0.12644
# [919]	validation_0-rmse:0.03230	validation_1-rmse:0.12643
# [920]	validation_0-rmse:0.03224	validation_1-rmse:0.12643
# [921]	validation_0-rmse:0.03220	validation_1-rmse:0.12644
# [922]	validation_0-rmse:0.03212	validation_1-rmse:0.12643
# [923]	validation_0-rmse:0.03208	validation_1-rmse:0.12642
# [924]	validation_0-rmse:0.03206	validation_1-rmse:0.12642
# [925]	validation_0-rmse:0.03205	validation_1-rmse:0.12641
# [926]	validation_0-rmse:0.03201	validation_1-rmse:0.12641
# [927]	validation_0-rmse:0.03198	validation_1-rmse:0.12641
# [928]	validation_0-rmse:0.03195	validation_1-rmse:0.12641
# [929]	validation_0-rmse:0.03192	validation_1-rmse:0.12641
# [930]	validation_0-rmse:0.03185	validation_1-rmse:0.12640
# [931]	validation_0-rmse:0.03182	validation_1-rmse:0.12640
# [932]	validation_0-rmse:0.03175	validation_1-rmse:0.12639
# [933]	validation_0-rmse:0.03172	validation_1-rmse:0.12638
# [934]	validation_0-rmse:0.03168	validation_1-rmse:0.12637
# [935]	validation_0-rmse:0.03165	validation_1-rmse:0.12639
# [936]	validation_0-rmse:0.03161	validation_1-rmse:0.12638
# [937]	validation_0-rmse:0.03159	validation_1-rmse:0.12637
# [938]	validation_0-rmse:0.03156	validation_1-rmse:0.12637
# [939]	validation_0-rmse:0.03152	validation_1-rmse:0.12637
# [940]	validation_0-rmse:0.03149	validation_1-rmse:0.12637
# [941]	validation_0-rmse:0.03146	validation_1-rmse:0.12636
# [942]	validation_0-rmse:0.03145	validation_1-rmse:0.12636
# [943]	validation_0-rmse:0.03140	validation_1-rmse:0.12637
# [944]	validation_0-rmse:0.03137	validation_1-rmse:0.12636
# [945]	validation_0-rmse:0.03134	validation_1-rmse:0.12636
# [946]	validation_0-rmse:0.03129	validation_1-rmse:0.12636
# [947]	validation_0-rmse:0.03126	validation_1-rmse:0.12636
# [948]	validation_0-rmse:0.03124	validation_1-rmse:0.12636
# [949]	validation_0-rmse:0.03120	validation_1-rmse:0.12636
# [950]	validation_0-rmse:0.03116	validation_1-rmse:0.12635
# [951]	validation_0-rmse:0.03114	validation_1-rmse:0.12635
# [952]	validation_0-rmse:0.03111	validation_1-rmse:0.12634
# [953]	validation_0-rmse:0.03107	validation_1-rmse:0.12634
# [954]	validation_0-rmse:0.03104	validation_1-rmse:0.12635
# [955]	validation_0-rmse:0.03097	validation_1-rmse:0.12634
# [956]	validation_0-rmse:0.03094	validation_1-rmse:0.12634
# [957]	validation_0-rmse:0.03090	validation_1-rmse:0.12634
# [958]	validation_0-rmse:0.03086	validation_1-rmse:0.12633
# [959]	validation_0-rmse:0.03081	validation_1-rmse:0.12632
# [960]	validation_0-rmse:0.03076	validation_1-rmse:0.12632
# [961]	validation_0-rmse:0.03072	validation_1-rmse:0.12631
# [962]	validation_0-rmse:0.03068	validation_1-rmse:0.12632
# [963]	validation_0-rmse:0.03066	validation_1-rmse:0.12632
# [964]	validation_0-rmse:0.03063	validation_1-rmse:0.12632
# [965]	validation_0-rmse:0.03060	validation_1-rmse:0.12631
# [966]	validation_0-rmse:0.03059	validation_1-rmse:0.12631
# [967]	validation_0-rmse:0.03054	validation_1-rmse:0.12630
# [968]	validation_0-rmse:0.03052	validation_1-rmse:0.12629
# [969]	validation_0-rmse:0.03049	validation_1-rmse:0.12628
# [970]	validation_0-rmse:0.03047	validation_1-rmse:0.12628
# [971]	validation_0-rmse:0.03045	validation_1-rmse:0.12628
# [972]	validation_0-rmse:0.03040	validation_1-rmse:0.12628
# [973]	validation_0-rmse:0.03039	validation_1-rmse:0.12627
# [974]	validation_0-rmse:0.03035	validation_1-rmse:0.12627
# [975]	validation_0-rmse:0.03031	validation_1-rmse:0.12627
# [976]	validation_0-rmse:0.03028	validation_1-rmse:0.12626
# [977]	validation_0-rmse:0.03025	validation_1-rmse:0.12626
# [978]	validation_0-rmse:0.03023	validation_1-rmse:0.12626
# [979]	validation_0-rmse:0.03021	validation_1-rmse:0.12625
# [980]	validation_0-rmse:0.03017	validation_1-rmse:0.12625
# [981]	validation_0-rmse:0.03014	validation_1-rmse:0.12625
# [982]	validation_0-rmse:0.03010	validation_1-rmse:0.12624
# [983]	validation_0-rmse:0.03009	validation_1-rmse:0.12623
# [984]	validation_0-rmse:0.03003	validation_1-rmse:0.12622
# [985]	validation_0-rmse:0.02998	validation_1-rmse:0.12621
# [986]	validation_0-rmse:0.02993	validation_1-rmse:0.12620
# [987]	validation_0-rmse:0.02987	validation_1-rmse:0.12619
# [988]	validation_0-rmse:0.02986	validation_1-rmse:0.12619
# [989]	validation_0-rmse:0.02983	validation_1-rmse:0.12619
# [990]	validation_0-rmse:0.02981	validation_1-rmse:0.12619
# [991]	validation_0-rmse:0.02979	validation_1-rmse:0.12618
# [992]	validation_0-rmse:0.02972	validation_1-rmse:0.12617
# [993]	validation_0-rmse:0.02968	validation_1-rmse:0.12618
# [994]	validation_0-rmse:0.02965	validation_1-rmse:0.12617
# [995]	validation_0-rmse:0.02961	validation_1-rmse:0.12617
# [996]	validation_0-rmse:0.02958	validation_1-rmse:0.12616
# [997]	validation_0-rmse:0.02956	validation_1-rmse:0.12615
# [998]	validation_0-rmse:0.02951	validation_1-rmse:0.12616
# [999]	validation_0-rmse:0.02948	validation_1-rmse:0.12616
# [1000]	validation_0-rmse:0.02947	validation_1-rmse:0.12616
# [1001]	validation_0-rmse:0.02945	validation_1-rmse:0.12616
# [1002]	validation_0-rmse:0.02940	validation_1-rmse:0.12616
# [1003]	validation_0-rmse:0.02936	validation_1-rmse:0.12616
# [1004]	validation_0-rmse:0.02932	validation_1-rmse:0.12617
# [1005]	validation_0-rmse:0.02931	validation_1-rmse:0.12616
# [1006]	validation_0-rmse:0.02928	validation_1-rmse:0.12616
# [1007]	validation_0-rmse:0.02925	validation_1-rmse:0.12616
# [I 2021-11-16 20:30:30,633] Trial 9 finished with value: 0.1261527817536986 and parameters: {'base_score': 0.6866286065017388, 'max_depth': 10, 'n_jobs': 17, 'min_child_weight': 9, 'n_estimators': 1941, 'colsample_bytree': 0.8073613974252026, 'subsample': 0.7739952989335789, 'learning_rate': 0.03811785096815648}. Best is trial 2 with value: 0.12469757974374289.
# FrozenTrial(number=2, values=[0.12469757974374289], datetime_start=datetime.datetime(2021, 11, 16, 20, 28, 31, 793079), datetime_complete=datetime.datetime(2021, 11, 16, 20, 28, 54, 362527), params={'base_score': 0.7496883842846649, 'max_depth': 11, 'n_jobs': 14, 'min_child_weight': 7, 'n_estimators': 1830, 'colsample_bytree': 0.7735299481694955, 'subsample': 0.8988956362147709, 'learning_rate': 0.020664667417701982}, distributions={'base_score': UniformDistribution(high=0.76, low=0.6), 'max_depth': IntUniformDistribution(high=14, low=10, step=1), 'n_jobs': IntUniformDistribution(high=18, low=14, step=1), 'min_child_weight': IntUniformDistribution(high=10, low=6, step=1), 'n_estimators': IntUniformDistribution(high=2194, low=1594, step=1), 'colsample_bytree': UniformDistribution(high=0.86, low=0.7), 'subsample': UniformDistribution(high=0.9, low=0.73), 'learning_rate': UniformDistribution(high=0.06, low=0.01)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=2, state=TrialState.COMPLETE, value=None)

# %% [markdown]
# # Catboost

# %%
# normalize training data
train_data = dfTrain.copy()
train_data = process_data(train_data, keep_col=['price'])

# split training data into test and training split
X_train, X_test = train_test_split(train_data, test_size=0.10, random_state=42)

# remove apartments with very high price from training data
qhigh = X_train["price"].quantile(0.999)
X_train = X_train[(train_data["price"] < qhigh)]

# get price columns 
y_train = X_train.pop("price")
y_test = X_test.pop("price")

cols = X_train.columns

# log prices
y_train = np.log(y_train)

scaler = preprocessing.StandardScaler().fit(X_train)
imputor=IterativeImputer(
    estimator=BayesianRidge(),
    imputation_order='ascending', 
    max_iter=100,
    tol=1e-5)

X_train = imputor.fit_transform(X_train)
X_train = scaler.transform(X_train)

X_test = imputor.fit_transform(X_test)
X_test = scaler.transform(X_test)


"""
catboost_regressor = CatBoostRegressor(
    n_estimators=2180,
    learning_rate=0.04364756663567214,
    thread_count=-1,
    depth=8,
    silent=True,
    random_state=42,
    bagging_temperature=0.16948019209038917
)
"""
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 1500, 2800)
    learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
    depth = trial.suggest_int('depth', 5, 12)
    bagging_temperature = trial.suggest_uniform('bagging_temperature', 0.05, 0.3)

    clf=CatBoostRegressor(
        n_estimators=n_estimators,
        learning_rate=learning_rate,
        thread_count=-1,
        depth=depth,
        silent=True,
        random_state=42,
        bagging_temperature=bagging_temperature
    )

    clf.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=0, early_stopping_rounds=10)
    cat_boost_prediction = clf.predict(X_test)
    cat_boost_prediction = np.exp(cat_boost_prediction)

    return np.sqrt(mean_squared_log_error(cat_boost_prediction, y_test))

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=5)
print(study.best_trial)
# Out:
# C:\Users\erikm\AppData\Local\Temp/ipykernel_7964/3870565040.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   X_train = X_train[(train_data["price"] < qhigh)]
# C:\Users\erikm\miniconda3\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# C:\Users\erikm\miniconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\erikm\miniconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2021-11-16 21:33:16,513] A new study created in memory with name: no-name-56c2c238-da96-476e-9b4a-2e9b9932036b
# [I 2021-11-16 21:35:19,810] Trial 0 finished with value: 0.14827788748084952 and parameters: {'n_estimators': 2572, 'learning_rate': 0.02187446040965243, 'depth': 12, 'bagging_temperature': 0.14190010939091607}. Best is trial 0 with value: 0.14827788748084952.
# [I 2021-11-16 21:35:21,622] Trial 1 finished with value: 0.15907758154063162 and parameters: {'n_estimators': 2717, 'learning_rate': 0.0417690769577881, 'depth': 6, 'bagging_temperature': 0.13560244833904733}. Best is trial 0 with value: 0.14827788748084952.
# [I 2021-11-16 21:35:28,196] Trial 2 finished with value: 0.1540579717224881 and parameters: {'n_estimators': 1841, 'learning_rate': 0.021467649745829806, 'depth': 8, 'bagging_temperature': 0.08177135246802035}. Best is trial 0 with value: 0.14827788748084952.
# [I 2021-11-16 21:35:33,956] Trial 3 finished with value: 0.1458287010831501 and parameters: {'n_estimators': 2310, 'learning_rate': 0.06672125444809872, 'depth': 9, 'bagging_temperature': 0.16256421330675563}. Best is trial 3 with value: 0.1458287010831501.
# [I 2021-11-16 21:35:46,595] Trial 4 finished with value: 0.14457284224062036 and parameters: {'n_estimators': 2043, 'learning_rate': 0.09604047649624867, 'depth': 10, 'bagging_temperature': 0.16597749203341156}. Best is trial 4 with value: 0.14457284224062036.
# FrozenTrial(number=4, values=[0.14457284224062036], datetime_start=datetime.datetime(2021, 11, 16, 21, 35, 33, 956276), datetime_complete=datetime.datetime(2021, 11, 16, 21, 35, 46, 595139), params={'n_estimators': 2043, 'learning_rate': 0.09604047649624867, 'depth': 10, 'bagging_temperature': 0.16597749203341156}, distributions={'n_estimators': IntUniformDistribution(high=2800, low=1500, step=1), 'learning_rate': UniformDistribution(high=0.1, low=0.01), 'depth': IntUniformDistribution(high=12, low=5, step=1), 'bagging_temperature': UniformDistribution(high=0.3, low=0.05)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=4, state=TrialState.COMPLETE, value=None)

# %% [markdown]
# # Random Forest

# %%
# normalize training data
train_data = dfTrain.copy()
train_data = process_data(train_data, keep_col=['price'])

# split training data into test and training split
X_train, X_test = train_test_split(train_data, test_size=0.10, random_state=42)

# remove apartments with very high price from training data
qhigh = X_train["price"].quantile(0.999)
X_train = X_train[(train_data["price"] < qhigh)]

# get price columns 
y_train = X_train.pop("price")
y_test = X_test.pop("price")

cols = X_train.columns

# log prices
y_train = np.log(y_train)

scaler = preprocessing.StandardScaler().fit(X_train)
imputor=IterativeImputer(
    estimator=BayesianRidge(),
    imputation_order='ascending', 
    max_iter=100,
    tol=1e-5)

X_train = imputor.fit_transform(X_train)
X_train = scaler.transform(X_train)

X_test = imputor.fit_transform(X_test)
X_test = scaler.transform(X_test)


"""
random_forest_regressor = RandomForestRegressor(
    n_estimators=100,
    criterion='mse',
    max_depth=None,
#     min_samples_split=2,
#     min_samples_leaf=2,
    min_weight_fraction_leaf=0.0,
    max_features='auto',
    max_leaf_nodes=None,
    min_impurity_decrease=0.0,
    bootstrap=True,
    oob_score=False,
    n_jobs=None,
    random_state=42,
    verbose=0,
    warm_start=False,
    ccp_alpha=0.0,
    max_samples=None
)
"""
# 0.146
# Trial 1 finished with value: 0.14516572314604645 and parameters: {'n_estimators': 361, 'max_leaf_nodes': 7728}
# Trial 1 finished with value: 0.14511747770969016 and parameters: {'n_estimators': 333, 'max_leaf_nodes': 9732}

def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 300, 400)
    #max_depth = trial.suggest_int("max_depth", 18, 32, log=True)
    #min_samples_split = trial.suggest_int('min_samples_split', 60, 120)
    #min_samples_leaf = trial.suggest_int('min_samples_leaf', 25, 65)
    max_leaf_nodes = trial.suggest_int('max_leaf_nodes', 7000, 10000)
    #max_features = trial.suggest_categorical('max_features', ['auto', 'sqrt','log2'])

    clf=RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=None,
        #min_samples_split=min_samples_split,
        #min_samples_leaf=min_samples_leaf,
        min_weight_fraction_leaf=0.0,
        max_features='auto',
        max_leaf_nodes=max_leaf_nodes,
        min_impurity_decrease=0.0,
        bootstrap=True,
        oob_score=False,
        n_jobs=None,
        random_state=42,
        verbose=0,
        warm_start=False,
        ccp_alpha=0.0,
        max_samples=None
    )

    clf.fit(X_train, y_train)
    random_forest_prediction = clf.predict(X_test)
    random_forest_prediction = np.exp(random_forest_prediction)

    return np.sqrt(mean_squared_log_error(random_forest_prediction, y_test))

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=5)
print(study.best_trial)
# Out:
# C:\Users\erikm\AppData\Local\Temp/ipykernel_16168/3221443897.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   X_train = X_train[(train_data["price"] < qhigh)]
# C:\Users\erikm\miniconda3\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# C:\Users\erikm\miniconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\erikm\miniconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2021-11-16 22:25:26,241] A new study created in memory with name: no-name-55e5ec17-45db-411b-aebf-0780560e05d1
# [I 2021-11-16 22:26:42,568] Trial 0 finished with value: 0.14516143294393405 and parameters: {'n_estimators': 367, 'max_leaf_nodes': 8188}. Best is trial 0 with value: 0.14516143294393405.
# [I 2021-11-16 22:27:52,626] Trial 1 finished with value: 0.14511747770969016 and parameters: {'n_estimators': 333, 'max_leaf_nodes': 9732}. Best is trial 1 with value: 0.14511747770969016.
# [I 2021-11-16 22:29:09,844] Trial 2 finished with value: 0.14519095854407266 and parameters: {'n_estimators': 368, 'max_leaf_nodes': 8365}. Best is trial 1 with value: 0.14511747770969016.
# [I 2021-11-16 22:30:33,078] Trial 3 finished with value: 0.14524646820814577 and parameters: {'n_estimators': 388, 'max_leaf_nodes': 8235}. Best is trial 1 with value: 0.14511747770969016.
# [I 2021-11-16 22:31:52,698] Trial 4 finished with value: 0.14516655991144764 and parameters: {'n_estimators': 363, 'max_leaf_nodes': 8416}. Best is trial 1 with value: 0.14511747770969016.
# FrozenTrial(number=1, values=[0.14511747770969016], datetime_start=datetime.datetime(2021, 11, 16, 22, 26, 42, 569000), datetime_complete=datetime.datetime(2021, 11, 16, 22, 27, 52, 626704), params={'n_estimators': 333, 'max_leaf_nodes': 9732}, distributions={'n_estimators': IntUniformDistribution(high=400, low=300, step=1), 'max_leaf_nodes': IntUniformDistribution(high=10000, low=7000, step=1)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=1, state=TrialState.COMPLETE, value=None)

# %% [markdown]
# # Ada boosting

# %%
# normalize training data
train_data = dfTrain.copy()
train_data = process_data(train_data, keep_col=['price'])

# split training data into test and training split
X_train, X_test = train_test_split(train_data, test_size=0.10, random_state=42)

# remove apartments with very high price from training data
qhigh = X_train["price"].quantile(0.999)
X_train = X_train[(train_data["price"] < qhigh)]

# get price columns 
y_train = X_train.pop("price")
y_test = X_test.pop("price")

cols = X_train.columns

# log prices
y_train = np.log(y_train)

scaler = preprocessing.StandardScaler().fit(X_train)
imputor=IterativeImputer(
    estimator=BayesianRidge(),
    imputation_order='ascending', 
    max_iter=100,
    tol=1e-5)

X_train = imputor.fit_transform(X_train)
X_train = scaler.transform(X_train)

X_test = imputor.fit_transform(X_test)
X_test = scaler.transform(X_test)


"""
ada_boost_regressor = AdaBoostRegressor(
    n_estimators=1500,
    learning_rate=0.05,
    loss='square',
    random_state=42
)
"""
# 0.304
# 0.3039 {'n_estimators': 713, 'learning_rate': 0.17754141972985152} 
# 0.296 {'n_estimators': 949, 'learning_rate': 0.02833005273221735}
# 0.2938 {'n_estimators': 650, 'learning_rate': 0.05553081486523326}

def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 600, 1100)
    learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.06)

    clf=AdaBoostRegressor(
        n_estimators=n_estimators,
        learning_rate=learning_rate,
        loss='square',
        random_state=42
    )

    clf.fit(X_train, y_train)
    ada_boost_prediction = clf.predict(X_test)
    ada_boost_prediction = np.exp(ada_boost_prediction)

    return np.sqrt(mean_squared_log_error(ada_boost_prediction, y_test))

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=5)
print(study.best_trial)
# Out:
# C:\Users\erikm\AppData\Local\Temp/ipykernel_16168/2022143231.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   X_train = X_train[(train_data["price"] < qhigh)]
# C:\Users\erikm\miniconda3\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# C:\Users\erikm\miniconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\erikm\miniconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2021-11-16 22:54:52,172] A new study created in memory with name: no-name-417f2d19-15eb-4452-b495-e594a25c4c85
# [I 2021-11-16 22:55:25,741] Trial 0 finished with value: 0.300660822366838 and parameters: {'n_estimators': 620, 'learning_rate': 0.03286704071648859}. Best is trial 0 with value: 0.300660822366838.
# [I 2021-11-16 22:56:08,341] Trial 1 finished with value: 0.3013101446407485 and parameters: {'n_estimators': 754, 'learning_rate': 0.027310725327456868}. Best is trial 0 with value: 0.300660822366838.
# [I 2021-11-16 22:56:38,773] Trial 2 finished with value: 0.29386621821893455 and parameters: {'n_estimators': 650, 'learning_rate': 0.05553081486523326}. Best is trial 2 with value: 0.29386621821893455.
# [I 2021-11-16 22:57:20,230] Trial 3 finished with value: 0.31431176076257117 and parameters: {'n_estimators': 613, 'learning_rate': 0.011304113145412905}. Best is trial 2 with value: 0.29386621821893455.
# [I 2021-11-16 22:57:56,702] Trial 4 finished with value: 0.30678299904493306 and parameters: {'n_estimators': 628, 'learning_rate': 0.026276653091460343}. Best is trial 2 with value: 0.29386621821893455.
# FrozenTrial(number=2, values=[0.29386621821893455], datetime_start=datetime.datetime(2021, 11, 16, 22, 56, 8, 342857), datetime_complete=datetime.datetime(2021, 11, 16, 22, 56, 38, 773483), params={'n_estimators': 650, 'learning_rate': 0.05553081486523326}, distributions={'n_estimators': IntUniformDistribution(high=1100, low=600, step=1), 'learning_rate': UniformDistribution(high=0.06, low=0.01)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=2, state=TrialState.COMPLETE, value=None)
